# %% [markdown]
# # Set up and process metadata

# %%
import csv
import numpy as np
from dataclasses import dataclass
from sys import argv

def normalize(results, spec_to_metadata = None):
    total = 0
    if spec_to_metadata:
        for key,thing in results.items():
            size = float(spec_to_metadata[key]['genome_size'])
            total += size * thing.seq_abund
        for key, thing in results.items():
            size = float(spec_to_metadata[key]['genome_size'])
            thing.seq_abund = thing.seq_abund * size / total
    else:
        for thing in results.values():
            total += thing.seq_abund 
        for thing in results.values():
            thing.seq_abund = thing.seq_abund/total

@dataclass
class tax_result:
    species: str
    genus: str
    abund: float
    seq_abund: float

@dataclass
class gen_abund:
    genus: str
    seq_abund: float

def get_spec_to_metadata(file_path, ganon_input):
    used_genomes = set()
    with open(ganon_input,'r') as f:
        for line in f:
            used = line.split('\t')[0].split('/')[-1].split('.fa')[0]
            used_genomes.add(used)
    spec_to_metadata = {}
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            if row['accession'] in used_genomes:
                spec = row['gtdb_taxonomy'].split(';')[-1]
                spec_to_metadata[spec] = row
            # if row['gtdb_representative'] == 'y':
            #     spec = row['gtdb_taxonomy'].split(';')[-1]
            #     spec_to_metadata[spec] = row
            # elif row['gtdb_taxonomy'].split(';')[-1] not in spec_to_metadata:
            #     spec = row['gtdb_taxonomy'].split(';')[-1]
            #     spec_to_metadata[spec] = row
    return spec_to_metadata

def read_ganon_file(file_path, species_name_to_spec_and_genus, spec_to_metadata):
    taxonomic_data = {}
    gen_data  = {}
    with open(file_path, 'r') as f:
        for line in f:
            spl = line.split('\t')
            if spl[0] == 'species':
                name = spl[3]
                num_seqs = float(spl[-2])
                spec = species_name_to_spec_and_genus[name]
                species = spec[1]
                genus = spec[0]
                abund = 0
                seq_abund = num_seqs
                taxonomic_data[species] = tax_result(species, genus, abund, seq_abund)
            if spl[0] == 'genus':
                num_seqs = float(spl[-2])
                genus = f"g__{spl[3]}"
                gen_data[genus] = gen_abund(genus,num_seqs)
                
    normalize(taxonomic_data)
    normalize(gen_data)
    return (taxonomic_data, gen_data)

def read_kraken_file(file_path, species_name_to_spec_and_genus, spec_to_metadata, cutoff):
    tax_data = {}
    gen_data = {}
    with open(file_path, 'r') as f:
        for row in f:
            spl = row.split('\t')
            if spl[3] == 'S':
                spec = spl[-1].strip()
                species = species_name_to_spec_and_genus[spec][1]
                seq_abund = float(spl[0])
                if seq_abund > cutoff:
                    res = tax_result(species, 'NA', 0, seq_abund)
                    tax_data[species] = res
            if spl[3] == 'G':
                genus = f"g__{spl[-1].strip()}"
                gen_data[genus] = gen_abund(genus,float(spl[0]))

    normalize(tax_data)
    normalize(gen_data)
    return (tax_data,gen_data)  

def read_kmcp_file(file_path, species_name_to_spec_and_genus, spec_to_metadata):
    tax_data = {}
    gen_data = {}
    with open(file_path, 'r') as f:
        for row in f:
            if '@' in row:
                continue
            spl = row.split('\t')
            if spl[1] == 'species':
                spec = spl[3].split('|')[-1].rstrip()
                species = species_name_to_spec_and_genus[spec][1]
                genus = species_name_to_spec_and_genus[spec][0]
                seq_abund = float(spl[-1].rstrip())
                res = tax_result(species, genus, 0, seq_abund)
                tax_data[species] = res
            if spl[1] == 'genus':
                genus = spl[3].split('|')[-1].rstrip()
                genus = f"g__{genus}"
                #gen_data[genus] = gen_abund(genus,float(spl[-1].rstrip()))

    normalize(gen_data)
    normalize(tax_data, spec_to_metadata)
    gen_data = {}
    for thing in tax_data.values():
        if thing.genus not in gen_data:
            gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
        else:
            gen_data[thing.genus].seq_abund += thing.seq_abund
    normalize(gen_data)
    return (tax_data, gen_data)   
    
def read_bac_to_gtdb(file_path):
    ref_to_spec_and_genus = {}
    species_name_to_spec_and_genus = {}
    with open(file_path, 'r') as f:
        for line in f:
            spl = line.strip().split("\t")
            ref = spl[0][3:]
            spec_and_genus = spl[1].split(';')[-2:]
            ref_to_spec_and_genus[ref] = spec_and_genus
            spec_string = spl[1].split(';')[-1][3:]
            species_name_to_spec_and_genus[spec_string] = spec_and_genus
    return (ref_to_spec_and_genus,species_name_to_spec_and_genus)

def truth(file_path, spec_to_metadata, spec90 = False):
    taxonomic_data = dict()
    results = []
    with open(file_path, 'r') as f:
        csv_reader = csv.reader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            spec = spl[0].split(';')[-2:]
            seq_abund = float(spl[1])
            size = float(spec_to_metadata[spec[1]]['genome_size'])
            data = tax_result(spec[1], spec[0], size, seq_abund)
            if spec90:
                if len(results) >= 50:
                    break
            results.append(data)
    total_cov = 0
    total_seq = 0
    for r in results:
        total_cov += r.abund * r.seq_abund
        total_seq += r.seq_abund
    for r in results:
        r.abund = r.abund * r.seq_abund / total_cov
        #r.seq_abund = r.seq_abund / total_seq
        if r.species in taxonomic_data:
            #print(r.species)
            taxonomic_data[r.species].seq_abund += r.seq_abund 
            taxonomic_data[r.species].abund += r.abund 
        else:
            taxonomic_data[r.species] = r

    return taxonomic_data

def read_sylph(file_path, ref_to_spec):
    sample_to_taxonomic_data = dict()
    sample_to_genus_data = dict()
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            query = row['Sample_file'].split('/')[-1].split('_')
            diff = int(query[0][-2:])
            it = int(query[1])
            if (diff,it) in sample_to_taxonomic_data:
                taxonomic_data = sample_to_taxonomic_data[(diff,it)]
            else:
                taxonomic_data = {}
                sample_to_taxonomic_data[(diff,it)] = taxonomic_data
            if 'Query_file' in row:
                ref = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            else:
                ref = row['Genome_file'].split('/')[-1].split('_genomic')[0][3:]
            spec = ref_to_spec[ref]
            r = tax_result(spec[1],spec[0], float(row['Taxonomic_abundance'])/100, float(row['Sequence_abundance'])/100)
            taxonomic_data[spec[1]] = r
    for key,tax_data in sample_to_taxonomic_data.items():
        gen_data = {}
        for thing in tax_data.values():
            if thing.genus not in gen_data:
                gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
            else:
                gen_data[thing.genus].seq_abund += thing.seq_abund
        sample_to_genus_data[key] = gen_data
    return (sample_to_taxonomic_data, sample_to_genus_data)

def read_metaphlan(file_path, spec_to_metadata, r207_to_r89):
    taxonomic_data = dict()
    results = []
    with open(file_path, 'r') as f:
        for row in f:
            if 's__' in row:
                spl = row.split('\t')[0].split(';')[-2:]
                genus = spl[0]
                spec = spl[1]
                key = tuple([genus, spec])
                if key not in r207_to_r89:
                    print(spec)
                    continue
                r89 = r207_to_r89[key]
                r89_spec = r89[1]
                r89_genus = r89[0]
                abund = row.split('\t')[-1].rstrip()
                size = spec_to_metadata[r89_spec]['genome_size']
                data = tax_result(r89_spec, r89_genus, float(abund), float(abund))
                taxonomic_data[r89_spec] = data
            # if 'g__' in row.split('\t')[0].split(';')[-1]:
            #     spl = row.split('\t')[0].split(';')[-2:]
            #     genus = spl[0]
            #     spec = spl[1]
            #     key = tuple([genus, spec])
            #     if key not in r207_to_r89:
            #         print(spec)
            #         continue
            #     r89 = r207_to_r89[key]
            #     r89_genus = r89[0]
            #     abund = row.split('\t')[-1].rstrip()
            #     data = gen_abund(r89_genus, float(abund))
            #     gen_data[r89_genus] = data


    normalize(taxonomic_data, spec_to_metadata)
    #normalize(taxonomic_data)
    gen_data = {}
    for thing in taxonomic_data.values():
        if thing.genus not in gen_data:
            gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
        else:
            gen_data[thing.genus].seq_abund += thing.seq_abund
    normalize(gen_data)
    return(taxonomic_data, gen_data)
    
def compare_to_truth( res, genus_res, truth, filename, debug = False):
    tp = 0
    fp = 0
    num_true = len(truth)
    num_pred = len(res)
    seq_abund_vec_res = []
    seq_abund_vec_truth = []

    genus_seq_abund_vec_res = []
    genus_seq_abund_vec_truth = []

    genus_to_abund_truth = dict()
    genus_to_abund_res = dict()
    for data in genus_res.values():
        if data.genus not in genus_to_abund_res:
            genus_to_abund_res[data.genus] = data.seq_abund
        else:
            genus_to_abund_res[data.genus] += data.seq_abund
            
    for data in truth.values():
        if data.genus not in genus_to_abund_truth:
            genus_to_abund_truth[data.genus] = data.seq_abund
        else:
            genus_to_abund_truth[data.genus] += data.seq_abund        

    for (genus, abund) in genus_to_abund_truth.items():
        if genus not in genus_to_abund_res:
            genus_seq_abund_vec_truth.append(abund)
            genus_seq_abund_vec_res.append(0)
        else:
            genus_seq_abund_vec_truth.append(abund)
            genus_seq_abund_vec_res.append(genus_to_abund_res[genus])
    for (genus,abund) in genus_to_abund_res.items():
        if genus not in genus_to_abund_truth:
            genus_seq_abund_vec_res.append(abund)
            genus_seq_abund_vec_truth.append(0)
    
    for spec, data in truth.items():
        seq_abund_vec_truth.append(data.seq_abund)
        if spec in res:
            #if debug:
            #    print(truth[spec], res[spec])
            seq_abund_vec_res.append(res[spec].seq_abund)
            tp += 1
        else:
            #if debug:
            #    print(spec, data)
            seq_abund_vec_res.append(0)
            #fp += 1
    for spec, data in res.items():
        if spec not in truth:
            if debug:
                print(data)
            fp += 1
            seq_abund_vec_res.append(res[spec].seq_abund)
            seq_abund_vec_truth.append(0)

    #seq_abund_vec_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
    #seq_abund_vec_res = seq_abund_vec_res / np.linalg.norm(seq_abund_vec_res,1)
    #genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
    #genus_seq_abund_vec_res = genus_seq_abund_vec_res / np.linalg.norm(genus_seq_abund_vec_res,1)


    norm_seq_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
    norm_seq_res = seq_abund_vec_res / np.linalg.norm(seq_abund_vec_res,1)
    genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
    genus_seq_abund_vec_res = genus_seq_abund_vec_res / np.linalg.norm(genus_seq_abund_vec_res,1)
    
    l1_seqabund = np.sum(np.abs(np.array(seq_abund_vec_res) - np.array(seq_abund_vec_truth)))
    l1_genus_seqabund = np.sum(np.abs(np.array(genus_seq_abund_vec_truth) - np.array(genus_seq_abund_vec_res)))

    l1_seqabund_species = (np.sum(np.abs(np.array(norm_seq_truth) - np.array(norm_seq_res))))

    sensitivity = tp/num_true
    precision = 1 - fp/num_pred

    print('---------------    ' + filename)
    print("F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct")
    f1 = 2 / (1 / sensitivity + 1 / precision)
    print(f1, l1_seqabund, l1_genus_seqabund, sensitivity, precision, num_pred, tp)
    return({"f1":f1, "l1":l1_seqabund, "sensitivity": sensitivity, "precision": precision,
            "num_pred": num_pred, "tp": tp, "l1genus": l1_genus_seqabund, "l1_constrain": l1_seqabund_species})

def print_ref_genomes(results, spec_to_metadata, outstring):
    f = open(outstring,'w')
    f.write("cat ")
    for species in results.keys():
        g = spec_to_metadata[species]['gtdb_genome_representative']
        st = f'/mnt/disks/1tb/benchmark/r89/kraken_genomes/{g}.fa'
        f.write(st)
        f.write(" ")
    f.write(" > temp_refs.fa")

# %%
def get_r207_to_r89(skani_file, r89_meta, r207_meta):

    # Initialize an empty dictionary to store the mapping from accession to gtdb_taxonomy
    accession_to_taxonomy_r89 = {}
    
    # Read the TSV file
    with open(r89_meta, mode='r') as f:
        tsv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in tsv_reader:
            accession = row['accession'][3:]
            taxonomy = tuple(row['gtdb_taxonomy'].split(';')[-2:])
            accession_to_taxonomy_r89[accession] = taxonomy

    # Initialize an empty dictionary to store the mapping from accession to gtdb_taxonomy
    accession_to_taxonomy_r207 = {}
    
    # Read the TSV file
    with open(r207_meta, mode='r') as f:
        tsv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in tsv_reader:
            accession = row['accession'][3:]
            taxonomy = tuple(row['gtdb_taxonomy'].split(';')[-2:])
            accession_to_taxonomy_r207[accession] = taxonomy
    # Initialize an empty dictionary to store the Ref_file as th
    # Initialize an empty dictionary to store the Ref_file as the key and the Query_file with the highest ANI as the value
    highest_ani_dict = {}
    
    # Read the CSV file
    with open(skani_file, mode='r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in csv_reader:
            # Extract relevant parts of the filename to create keys and values in the form "GCA_000182945.1"
            ref_key = row['Ref_file'].split('/')[-1].split('_genomic')[0]
            query_key = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            
            # Convert ANI to float for comparison
            ani = float(row['ANI'])
            
            # Update the dictionary
            if ref_key not in highest_ani_dict or ani > highest_ani_dict[ref_key]['ANI']:
                highest_ani_dict[ref_key] = {'Query': query_key, 'ANI': ani}

    ret = {}
    for key,value in highest_ani_dict.items():
        if value['ANI'] > 93:
            r207_tax = accession_to_taxonomy_r207[key]
            r89_tax = accession_to_taxonomy_r89[value['Query']]
            ret[r207_tax] = r89_tax
    return ret

r207_to_r89 = get_r207_to_r89('/mnt/disks/1tb/benchmark/r89-to-r207.tsv', 
                              '/mnt/disks/1tb/benchmark/r89/combined_metadata_r89.tsv', 
                              '/mnt/disks/1tb/benchmark/combined_metadata_r207.tsv')

# %%
spec_to_metadata = get_spec_to_metadata('/mnt/disks/1tb/benchmark/r89/combined_metadata_r89.tsv', '/mnt/disks/1tb/benchmark/r89/ganon-input.tsv')

(ref_to_spec,species_name_to_spec) = read_bac_to_gtdb('/mnt/disks/1tb/benchmark/r89/gtdb_combined_r89_taxonomy.tsv')

# %%
(sylph_results,sylph_gen_results) = read_sylph('/mnt/disks/1tb/simulation_reads/sylph_out/sylph_output.tsv', ref_to_spec)
#(sylph_results,sylph_gen_results) = read_sylph('/mnt/disks/1tb/simulation_reads/sylph_results.tsv', ref_to_spec)

all_stats = [[],[],[]] 
sylph_stats = [[],[],[]]
kmcp_stats = [[],[],[]]
ganon_stats = [[],[],[]]
kraken_stats = [[],[],[]]
metaphlan_stats = [[],[],[]]

sylph_stats_all = []
kmcp_stats_all = []
ganon_stats_all = []
kraken_stats_all = []
metaphlan_stats_all = []
kraken_cutoff = 0.01
exps = [90,96,98]
its = range(1,11)

#exps = [98]
#its = [5,7]
for (i,diff) in enumerate(exps):
    for it in its:
        files = [' ', f'/mnt/disks/1tb/simulation_reads/species{diff}/species{diff}_{it}.tsv',
               'sylph',
             f'/mnt/disks/1tb/simulation_reads/kmcp_out/species{diff}/species{diff}_{it}.kmcp.profile',
             f'/mnt/disks/1tb/simulation_reads/ganon_out/species{diff}/species{diff}_{it}.ganon.tre',
            f'/mnt/disks/1tb/simulation_reads/kraken_out/species{diff}/species{diff}_{it}_bracken_species.kreport',
            f'/mnt/disks/1tb/simulation_reads/metaphlan_out/species{diff}/species{diff}_{it}.metaphlan.gtdb',
              ]
        if diff == 90:
            truth_data = truth(files[1], spec_to_metadata, spec90 = True)
            truth_data_all = truth(files[1],spec_to_metadata, spec90=False)
        else:
            truth_data = truth(files[1], spec_to_metadata)
        # Test the functions
        files = files[2:]
        
        rg = "ref_genomes/"
        out = ""
        print(it,diff)
        for result in files:
            gen_results = None
            if 'ganon' in result:
                (results, gen_results) = read_ganon_file(result, species_name_to_spec, spec_to_metadata)
                out = f"{rg}{diff}_{it}.ganon.sh"
            elif 'sylph' in result:
                results = sylph_results[(diff,it)]
                gen_results = sylph_gen_results[(diff,it)]
                out = f"{rg}{diff}_{it}.sylph.sh"
            elif 'kraken' in result:
                (results,gen_results) = read_kraken_file(result, species_name_to_spec, spec_to_metadata, kraken_cutoff)
                out = f"{rg}{diff}_{it}.kraken.sh"
                #compare_to_truth(results, truth_data)
                #results = read_kraken_file(result, species_name_to_spec, spec_to_metadata, 0.01 / 100)
            elif 'kmcp' in result:
                out = f"{rg}{diff}_{it}.kmcp.sh"
                (results,gen_results) = read_kmcp_file(result, species_name_to_spec, spec_to_metadata)
            elif 'metaphlan' in result:
                if diff == 90:
                    continue
                out = f"{rg}{diff}_{it}.metaphlan.sh"
                (results,gen_results) = read_metaphlan(result, spec_to_metadata, r207_to_r89)

            debug = False
            if 'metaphlan' in result:
                debug = False
            stats = compare_to_truth(results, gen_results, truth_data, result, debug)
            all_stats[i].append((stats,diff,it, result))
            if diff == 90:
                bad_stats = compare_to_truth(results, gen_results, truth_data_all,result, debug)
                if 'sylph' in result:
                    sylph_stats_all.append(bad_stats)
                if 'kmcp' in result:
                    kmcp_stats_all.append(bad_stats)
                if 'ganon' in result:
                    ganon_stats_all.append(bad_stats)
                if 'kraken' in result:
                    kraken_stats_all.append(bad_stats)
                if 'metaphlan' in result:
                    metaphlan_stats_all.append(bad_stats)
            print_ref_genomes(results, spec_to_metadata, out)


    for stats,diff,it,result in all_stats[i]:
        if 'sylph' in result:
            sylph_stats[i].append(stats)
        if 'kmcp' in result:
            kmcp_stats[i].append(stats)
        if 'ganon' in result:
            ganon_stats[i].append(stats)
        if 'kraken' in result:
            kraken_stats[i].append(stats)
        if 'metaphlan' in result:
            metaphlan_stats[i].append(stats)
# Out:
# 1 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8043478260869565 0.6340586761828083 0.2316155295849191 0.74 0.8809523809523809 42 37
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3096234309623431 1.1568142623917925 1.1312546327472497 0.18781725888324874 0.8809523809523809 42 37
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6190476190476191 0.5336473126050111 0.21662012028641123 0.78 0.513157894736842 76 39
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3516483516483517 1.041763897181931 1.0038221612191425 0.2436548223350254 0.631578947368421 76 48
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.49557522123893805 0.6932825182669301 0.6638414662459927 0.56 0.4444444444444444 63 28
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.25384615384615383 1.209351466544061 1.080035034431641 0.16751269035532995 0.5238095238095238 63 33
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.13714285714285712 0.5624329694724188 0.8935103410143702 0.72 0.07578947368421052 475 36
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.375 0.6983512744781886 0.35072714402869204 0.6395939086294417 0.26526315789473687 475 126
# 2 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8478260869565218 0.6263296429054386 0.1124170911414569 0.78 0.9285714285714286 42 39
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.32911392405063294 1.2117196573360396 1.1762196664462996 0.2 0.9285714285714286 42 39
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5517241379310345 1.251566022923941 1.4996850027584843 0.64 0.48484848484848486 66 32
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3371647509578544 1.6432413915143433 1.4935918538726871 0.22564102564102564 0.6666666666666667 66 44
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5283018867924528 0.6049169584399867 0.6412419211796202 0.56 0.5 56 28
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.26294820717131473 1.1541650376226031 1.0176890165715577 0.16923076923076924 0.5892857142857143 56 33
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.20460358056265984 0.6997724668009437 0.9229807794511041 0.8 0.11730205278592376 341 40
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.4626865671641791 0.7509713292293501 0.35391030849902055 0.6358974358974359 0.36363636363636365 341 124
# 3 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8695652173913044 0.7906560425584112 0.12220246536882502 0.8 0.9523809523809523 42 40
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.33613445378151263 1.5754260376709341 1.4207013700952826 0.20408163265306123 0.9523809523809523 42 40
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5581395348837209 0.85439523615146 0.43717496044465065 0.72 0.45569620253164556 79 36
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.4 1.423139431288618 1.2406685177917178 0.28061224489795916 0.6962025316455696 79 55
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5405405405405405 0.8059264726000156 0.6317703398809673 0.6 0.4918032786885246 61 30
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.34241245136186776 1.3835819668946625 1.2255672781635945 0.22448979591836735 0.7213114754098361 61 44
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.13120000000000004 0.8555885373704486 1.2890754489473482 0.82 0.07130434782608697 575 41
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.35019455252918286 0.8804031199025609 0.3456612229560304 0.6887755102040817 0.23478260869565215 575 135
# 4 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7912087912087913 0.8499323405661858 0.08945808260203915 0.72 0.8780487804878049 41 36
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.30379746835443044 1.6882158255476243 1.575976811425435 0.1836734693877551 0.8780487804878049 41 36
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.510948905109489 0.8675760583499086 0.3345207456399878 0.7 0.4022988505747126 87 35
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.36042402826855124 1.527665097982738 1.4165795646458221 0.2602040816326531 0.5862068965517242 87 51
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.4444444444444444 0.8583262998249686 0.5847458995591891 0.48 0.4137931034482759 58 24
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.26771653543307083 1.5486254145198612 1.2481580533246144 0.17346938775510204 0.5862068965517242 58 34
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.14205607476635523 0.8575844449986241 1.4427953398914368 0.76 0.07835051546391758 485 38
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3935389133627019 0.913069588483981 0.3388539300093934 0.6836734693877551 0.27628865979381445 485 134
# 5 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8723404255319149 0.7873643180519861 0.08987900633798541 0.82 0.9318181818181819 44 41
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3416666666666667 1.5652394614247171 1.5099158599334523 0.20918367346938777 0.9318181818181819 44 41
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5737704918032787 0.8384005438875145 0.4119102562362352 0.7 0.48611111111111116 72 35
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3208955223880597 1.479735593553075 1.344271341660916 0.2193877551020408 0.5972222222222222 72 43
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.4696969696969697 0.8057228542531996 0.5353955731056682 0.62 0.3780487804878049 82 31
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.2661870503597122 1.4484594532875377 1.2528890036615268 0.18877551020408162 0.4512195121951219 82 37
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.13953488372093015 0.839634323433998 1.393264461125163 0.78 0.0766208251473477 509 39
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.37163120567375885 0.9276155965093433 0.31361873519239025 0.6683673469387755 0.2573673870333988 509 131
# 6 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8409090909090908 0.7683244040947099 0.09457404789177865 0.7551020408163265 0.9487179487179487 39 37
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.31223628691983124 1.5233689947737783 1.4552571361426812 0.18686868686868688 0.9487179487179487 39 37
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6115702479338844 0.8473443518798554 0.301857047266321 0.7551020408163265 0.5138888888888888 72 37
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.34814814814814815 1.52041093792973 1.2817453039502154 0.23737373737373738 0.6527777777777778 72 47
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.4770642201834863 0.7863220069750286 0.6032025073968931 0.5306122448979592 0.43333333333333335 60 26
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.24031007751937986 1.407817059871324 1.126005366937072 0.15656565656565657 0.5166666666666666 60 31
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.09728183118741053 0.835597019574743 1.4047334165003542 0.6938775510204082 0.05230769230769228 650 34
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.2806603773584905 1.181742792436717 0.22253783416953893 0.601010101010101 0.18307692307692303 650 119
# 7 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8478260869565218 0.693226001032117 0.09915833224394488 0.78 0.9285714285714286 42 39
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3277310924369748 1.3716609490790457 1.11242989028114 0.1989795918367347 0.9285714285714286 42 39
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5826771653543308 1.0626658430731442 1.129697191004873 0.74 0.48051948051948057 77 37
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.38095238095238093 1.5690449706819345 1.3434991700335155 0.2653061224489796 0.6753246753246753 77 52
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.39370078740157477 0.6987092365949958 0.7200302492317608 0.5 0.3246753246753247 77 25
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.2783882783882784 1.2295886182972926 0.9647676154394247 0.19387755102040816 0.49350649350649356 77 38
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.1416526138279933 0.8460532485305005 0.9263362709149026 0.84 0.07734806629834257 543 42
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3626522327469554 0.9346806738108879 0.3416581152391178 0.6836734693877551 0.24677716390423576 543 134
# 8 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.691358024691358 0.6787407281589215 0.18211048737306654 0.56 0.9032258064516129 31 28
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.2456140350877193 1.3361711036039068 1.2969895977284425 0.14213197969543148 0.9032258064516129 31 28
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5252525252525253 0.6796989752187673 0.28354423930106326 0.52 0.5306122448979591 49 26
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.2926829268292683 1.2791318063234136 1.2475326774066327 0.18274111675126903 0.7346938775510203 49 36
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.46341463414634143 0.681986856498095 0.634414455393485 0.38 0.59375 32 19
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.20087336244541487 1.267657077902959 1.214315687525488 0.116751269035533 0.71875 32 23
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.13733905579399133 0.6764698926387123 1.1418205741389702 0.64 0.07692307692307687 416 32
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.33278955954323003 0.6793160148538303 0.2790315703950171 0.5177664974619289 0.2451923076923077 416 102
# 9 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8478260869565218 0.5822187913335202 0.06082847392428826 0.78 0.9285714285714286 42 39
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3362068965517242 1.151610513928154 1.0714300200217184 0.20526315789473684 0.9285714285714286 42 39
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_9.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5736434108527132 0.6531259824460349 0.20107549522968635 0.74 0.4683544303797469 79 37
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_9.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.42379182156133827 1.1358848651922127 1.1003061650530692 0.3 0.7215189873417722 79 57
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_9.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5420560747663551 0.5887559763049832 0.4541965281571303 0.58 0.5087719298245614 57 29
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_9.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.29149797570850206 1.0914374394782442 0.9834503649207161 0.18947368421052632 0.631578947368421 57 36
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_9_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.1493055555555555 0.616660617968446 0.9381264870219225 0.86 0.08174904942965777 526 43
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_9_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.36312849162011174 0.7247718224334033 0.3396416672184744 0.6842105263157895 0.24714828897338403 526 130
# 10 90
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7954545454545455 0.685230808839385 0.0881702148139014 0.7 0.9210526315789473 38 35
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.30434782608695654 1.360687032758299 1.3312243677297853 0.18229166666666666 0.9210526315789473 38 35
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6551724137931033 0.7472381737707251 0.3660844384991575 0.76 0.5757575757575757 66 38
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species90/species90_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.37209302325581395 1.3653243438174978 1.3067342805675646 0.25 0.7272727272727273 66 48
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5274725274725275 0.7087941064654083 0.5540430103905754 0.48 0.5853658536585367 41 24
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species90/species90_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.24892703862660942 1.3297775477165457 1.2049548188188308 0.15104166666666666 0.7073170731707317 41 29
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.14525139664804473 0.7174108029292344 1.1974422951923098 0.78 0.08008213552361398 487 39
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species90/species90_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.3917525773195877 0.7177644040481496 0.3631178116178612 0.6927083333333334 0.2731006160164271 487 133
# 1 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8474576271186441 0.190518770088959 0.0963914492473569 0.7772020725388601 0.9316770186335404 161 150
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7129186602870814 0.4680802615525952 0.31090055423343566 0.772020725388601 0.6622222222222223 225 149
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5685279187817259 0.6225663645789065 0.38360979021030334 0.5803108808290155 0.5572139303482587 201 112
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5123966942148761 0.6335251443167097 0.05717728623100263 0.8031088082901554 0.37621359223300976 412 155
# s__
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_1.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7377521613832853 0.600048050954716 0.21427428163746376 0.6632124352331606 0.8311688311688312 154 128
# 2 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8347826086956522 0.23831746933382533 0.14297680623711764 0.7578947368421053 0.9290322580645162 155 144
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6716417910447761 0.45494987280205074 0.2543946083846468 0.7105263157894737 0.6367924528301887 212 135
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5494505494505494 0.7924977606399451 0.5381439828968761 0.5263157894736842 0.5747126436781609 174 100
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.47972972972972977 0.6400486841582795 0.05857933789201218 0.7473684210526316 0.3532338308457711 402 142
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_2.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7409638554216867 0.6887685867475632 0.23120089369818964 0.6473684210526316 0.8661971830985915 142 123
# 3 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8555240793201132 0.3320789471948882 0.09601260241942718 0.7783505154639175 0.949685534591195 159 151
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7475728155339805 0.36888183702740296 0.16962018455759748 0.7938144329896907 0.7064220183486238 218 154
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5585106382978723 0.6716185654507516 0.4221135402407713 0.5412371134020618 0.5769230769230769 182 105
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5268630849220104 0.5668331977918435 0.06328893756699051 0.7835051546391752 0.3968668407310705 383 152
# s__Luminiphilus sp902547755
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_3.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7771428571428572 0.7198288744524344 0.3395334304715558 0.7010309278350515 0.8717948717948718 156 136
# 4 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8729281767955802 0.21333953736600952 0.1952313615512568 0.8020304568527918 0.9575757575757575 165 158
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7458432304038004 0.38558536243068164 0.26983828563500506 0.7969543147208121 0.7008928571428572 224 157
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6161616161616161 0.7682501414307503 0.5797673899366773 0.6192893401015228 0.6130653266331658 199 122
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5047021943573669 0.45703619804218887 0.06933327820037519 0.817258883248731 0.3650793650793651 441 161
# s__
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_4.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7932011331444759 0.42805859691644804 0.2622463466886041 0.7106598984771574 0.8974358974358975 156 140
# 5 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8668555240793202 0.1879367747873353 0.16203407190416214 0.7927461139896373 0.95625 160 153
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7317073170731707 0.4055508309946859 0.29224996582495166 0.7772020725388601 0.6912442396313364 217 150
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6210826210826211 0.5970028162805296 0.4274262344469253 0.5647668393782384 0.689873417721519 158 109
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5652173913043478 0.4655366475438302 0.11524067243508532 0.8082901554404145 0.43454038997214484 359 156
# s__
# s__Luminiphilus sp902547755
# s__
# s__
# s__Arsenophonus sp900343015
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_5.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.75 0.9598567886059037 0.5939655294392395 0.6683937823834197 0.8543046357615894 151 129
# 6 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7706422018348623 0.14966068080073125 0.0707947117893171 0.6528497409326425 0.9402985074626866 134 126
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6525198938992042 0.25341652912537377 0.17484686461867655 0.6373056994818653 0.6684782608695652 184 123
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5250737463126843 0.7396538358708864 0.5736461859220374 0.46113989637305697 0.6095890410958904 146 89
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5 0.3815295708889518 0.13309287966103098 0.616580310880829 0.4204946996466431 283 119
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_6.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7142857142857143 0.2768312017221751 0.22411230496097065 0.5958549222797928 0.8914728682170543 129 115
# 7 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8603988603988605 0.2825582340218547 0.24204713052703117 0.7743589743589744 0.967948717948718 156 151
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7198067632850241 0.4249589671847145 0.2777882822049752 0.764102564102564 0.680365296803653 219 149
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5785123966942148 0.6347225515635289 0.4925038782845984 0.5384615384615384 0.625 168 105
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5784499054820417 0.38718513631791585 0.13330624352787815 0.7846153846153846 0.45808383233532934 334 153
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_7.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7314285714285714 0.38559290394320533 0.2459420069426755 0.6564102564102564 0.8258064516129032 155 128
# 8 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8231707317073171 0.1543577090947582 0.08439456675601871 0.7219251336898396 0.9574468085106383 141 135
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7071240105540897 0.6982826062709735 0.3762357875426335 0.7165775401069518 0.6979166666666667 192 134
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5238095238095238 0.684414731997643 0.2655470432067245 0.47058823529411764 0.5906040268456376 149 88
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.49466192170818507 0.817644845100673 0.05587619964900506 0.7433155080213903 0.3706666666666667 375 139
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_8.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7300613496932515 0.4843645771841283 0.24250305564180885 0.6363636363636364 0.8561151079136691 139 119
# 9 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8587896253602305 0.1679659673224717 0.09919616519813783 0.7760416666666666 0.9612903225806452 155 149
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_9.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7405541561712847 0.5754594987116045 0.27327667583808185 0.765625 0.7170731707317073 205 147
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_9.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5541561712846347 0.7510823036353491 0.3601622162334907 0.5729166666666666 0.5365853658536586 205 110
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_9_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5195246179966044 0.8522640193676347 0.1434588113040877 0.796875 0.38539042821158687 397 153
# s__
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_9.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7349397590361446 1.3265862737259837 0.9203534982465861 0.6354166666666666 0.8714285714285714 140 122
# 10 96
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8530259365994236 0.12298650946081556 0.09230836713788072 0.7668393782383419 0.961038961038961 154 148
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species96/species96_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7007672634271099 0.6194931778755106 0.45205428318628565 0.7098445595854922 0.6919191919191919 198 137
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species96/species96_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.532967032967033 0.7608695926663359 0.5235712401115536 0.5025906735751295 0.5672514619883041 171 97
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species96/species96_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.46153846153846156 0.5296181423492412 0.07382166988747803 0.7150259067357513 0.3407407407407408 405 138
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species96/species96_10.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7594202898550724 0.3108385299367339 0.2335676319815598 0.6787564766839378 0.8618421052631579 152 131
# 1 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9226666666666665 0.09407952338350672 0.08112398480594786 0.865 0.9885714285714285 175 173
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8923076923076924 0.19347298842645044 0.09424651269025389 0.87 0.9157894736842105 190 174
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7643979057591623 0.2740652918688462 0.22700252682348782 0.73 0.8021978021978022 182 146
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6978922716627636 0.24896941818304902 0.0704530048409652 0.745 0.6563876651982379 227 149
# s__Desulfobacillus sp905339315
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_1.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7714285714285715 0.1970394549486023 0.1828843279782816 0.675 0.9 150 135
# 2 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9365079365079365 0.09482053658244319 0.07446797435775938 0.885 0.9943820224719101 178 177
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8804071246819338 0.15236852101836768 0.10115683541171817 0.865 0.8963730569948186 193 173
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.784 0.4054485323303764 0.338649100325887 0.735 0.84 175 147
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6682242990654206 0.2442760255021772 0.054270534562214846 0.715 0.6271929824561404 228 143
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_2.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7988826815642457 0.7805463439517839 0.59101698676179 0.715 0.9050632911392404 158 143
# 3 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9421052631578947 0.05939095655911328 0.056017174595416615 0.895 0.9944444444444445 180 179
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8956743002544527 0.07849458149728436 0.06472681713819757 0.88 0.9119170984455959 193 176
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8206521739130435 0.3356122222102372 0.30672681777197947 0.755 0.8988095238095238 168 151
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7518072289156627 0.1781617968116332 0.05179095241620495 0.78 0.7255813953488373 215 156
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_3.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8356545961002785 0.6450860160861813 0.6107885773823767 0.75 0.9433962264150944 159 150
# 4 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8986301369863013 0.12460001276885699 0.11930837826182683 0.82 0.9939393939393939 165 164
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.870712401055409 0.11274569999468231 0.08500229968622548 0.825 0.9217877094972067 179 165
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7632311977715878 0.3921244614383612 0.37319206933871035 0.685 0.8616352201257862 159 137
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6811594202898551 0.16371478009263304 0.07758180304704734 0.705 0.6588785046728972 214 141
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_4.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8022598870056497 0.5228211705357867 0.36485689133360055 0.71 0.922077922077922 154 142
# 5 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.935064935064935 0.14331505877603354 0.11201717563240718 0.9 0.972972972972973 185 180
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9090909090909091 0.18525042053415658 0.1347130774818371 0.9 0.9183673469387755 196 180
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8214285714285714 0.26162580110345834 0.2290448645803415 0.805 0.8385416666666666 192 161
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7191011235955056 0.18338763516857368 0.11159575674465859 0.8 0.653061224489796 245 160
# s__Desulfobacillus sp905339315
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_5.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8516483516483516 0.2496567788758811 0.2399954158894506 0.775 0.9451219512195121 164 155
# 6 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9721518987341771 0.10873942042638532 0.10137410682179046 0.96 0.9846153846153847 195 192
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.932367149758454 0.12028365504057803 0.10234061528240743 0.965 0.9018691588785047 214 193
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8637532133676091 0.33201287385895545 0.29586741493022145 0.84 0.8888888888888888 189 168
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7831858407079646 0.1347645497176148 0.11186531939199006 0.885 0.7023809523809523 252 177
# s__
# s__Arsenophonus sp900343015
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_6.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8486486486486486 0.39817495314747764 0.3707394269130224 0.785 0.9235294117647059 170 157
# 7 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9393139841688654 0.09997013779058575 0.09897166756808715 0.89 0.994413407821229 179 178
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8979591836734693 0.13012879773746316 0.10182915555985772 0.88 0.9166666666666666 192 176
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8270270270270269 0.29570361305948334 0.2738095241994898 0.765 0.9 170 153
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7037037037037037 0.1391955367721605 0.07339691648915378 0.76 0.6551724137931034 232 152
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_7.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8156424581005588 0.3475907017487528 0.29343541545753915 0.73 0.9240506329113924 158 146
# 8 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9234828496042218 0.1567823349498955 0.1500508096993723 0.875 0.9776536312849162 179 175
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8706467661691543 0.23428219715668325 0.22098663818391415 0.875 0.8663366336633663 202 175
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8090452261306534 0.37580653542694875 0.34202276690924405 0.805 0.8131313131313131 198 161
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6791666666666666 0.24885237310368793 0.2086106935340713 0.815 0.5821428571428571 280 163
# s__
# s__Desulfobacillus sp905339315
# s__
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_8.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7865168539325843 0.5830519310591423 0.45939213126878753 0.7 0.8974358974358975 156 140
# 9 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9509043927648579 0.13351198049315047 0.13036578465372334 0.92 0.983957219251337 187 184
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_9.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9073170731707317 0.14696131637387191 0.10971821273602893 0.93 0.8857142857142857 210 186
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_9.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8629441624365484 0.3201685846289791 0.24602129758627625 0.85 0.8762886597938144 194 170
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_9_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7443946188340806 0.1462098238488815 0.09717062724670468 0.83 0.6747967479674797 246 166
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_9.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8306010928961749 0.3600267305388305 0.252222815710838 0.76 0.9156626506024097 166 152
# 10 98
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9130434782608695 0.06965119552923556 0.059333707138686395 0.84 1.0 168 168
# ---------------    /mnt/disks/1tb/simulation_reads/kmcp_out/species98/species98_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8711340206185566 0.06952000083569568 0.06006885490581837 0.845 0.898936170212766 188 169
# ---------------    /mnt/disks/1tb/simulation_reads/ganon_out/species98/species98_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8210526315789475 0.2919180368423892 0.25154457635500777 0.78 0.8666666666666667 180 156
# ---------------    /mnt/disks/1tb/simulation_reads/kraken_out/species98/species98_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.6619047619047619 0.11416365477199789 0.043495544471101794 0.695 0.6318181818181818 220 139
# ---------------    /mnt/disks/1tb/simulation_reads/metaphlan_out/species98/species98_10.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8057142857142856 0.3891243534751859 0.24585947529860813 0.705 0.94 150 141

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm = 1/2.54  # centimeters in inches\n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 6})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})

fig, axes = plt.subplots(3, 3, figsize=(10* cm, 12* cm), sharey=True)
plt.subplots_adjust(hspace=0.4)

# Define the test setups and metrics
test_setups = ["95-97.5% ANI (50 genomes) + \n85-90% ANI (150 genomes; holdout)", 
               "95-97.5% ANI (200 genomes)",
               "97.5-99.9% ANI (200 genomes)"]
metrics = ['f1', 'precision', 'sensitivity']

y_positions = [1, 0.65, 0.30]
empty_stats = [[{'f1' : None, 'precision':None, 'sensitivity' :None}]]

# Loop through the test setups and metrics to fill the grid
for i, setup in enumerate(test_setups):
    if i == 0:
        methods = ['sylph profile', 'KMCP', 'ganon', 'Bracken', 'MetaPhlAn4']
        stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats, empty_stats]
    else:
        methods = ['sylph profile', 'KMCP', 'ganon', 'Bracken', 'MetaPhlAn4*']
        stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats, metaphlan_stats]
    for j, metric in enumerate(metrics):
        ax = axes[i, j]
        
        # Extract the data for this subplot
        data_to_plot = []
        for k, method_stats in enumerate(stats_l):
            #print(method_stats[i])
            method_data = [x[metric] for x in method_stats[i]]
            data_to_plot.append(method_data)
        
        # Create the boxplot with smaller width
        sns.barplot(data=data_to_plot, ax=ax, palette="muted", width=0.8)
        
        # Add labels
        ax.set_xticklabels(methods)
        ax.set_ylabel(metric.capitalize())

        if j == 1:
            ax.set_title(test_setups[i], fontsize=7)
        
        # Remove the top and right borders
        sns.despine(ax=ax)
        ax.tick_params(axis='x', rotation=75)
        if i != 2:
            ax.set_xticks([])
        
    # Add one title per row in the middle
    #fig.text(0.5, y_positions[i], setup, ha="center", va="center", fontsize=9)

# Show the grid of plots
#plt.tight_layout()
plt.savefig('figures/ani_r89_benchmark.svg')
plt.show()

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize empty lists to store data
time_data = []
cpu_time_data = []
memory_data = []

plt.rcParams.update({'font.size': 6})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})

# Function to read and parse benchmark data
def read_benchmark_data(filename, method, num_samples=1):
    with open(filename, 'r') as f:
        lines = f.readlines()
        headers = lines[0].strip().split('\t')
        values = lines[1].strip().split('\t')

        time_index = headers.index('s')
        cpu_time_index = headers.index('cpu_time')
        memory_index = headers.index('max_rss')

        time_data.append({'method': method, 'time': float(values[time_index])/num_samples})
        cpu_time_data.append({'method': method, 'cpu_time': float(values[cpu_time_index])/num_samples})
        memory_data.append({'method': method, 'memory': float(values[memory_index])/1000})

# Loop through each experiment and collect data
for exp in ['species90', 'species96', 'species98']:
    for method in [ 'kmcp', 'ganon', 'kraken', 'metaphlan']:#, 'motus']:
        for iter_file in glob.glob(f'benchmarks/{exp}/{exp}_*.{method}.benchmark'):
            read_benchmark_data(iter_file, method)

# Read sylph data (let's assume you have 30 samples for sylph)
read_benchmark_data('benchmarks/sylph.benchmark', 'sylph', num_samples=30)

# Convert lists of dictionaries to DataFrames
time_df = pd.DataFrame(time_data)
cpu_time_df = pd.DataFrame(cpu_time_data)
memory_df = pd.DataFrame(memory_data)

method_to_label = {
    'ganon': 'ganon',
    'kmcp': 'KMCP',
    'kraken': 'Bracken',
    'sylph': 'sylph profile',
    'metaphlan': 'MetaPhlAn4',
    #'motus': 'motus'
    
}


# Replace the method names in the DataFrames
time_df['method'] = time_df['method'].map(method_to_label)
cpu_time_df['method'] = cpu_time_df['method'].map(method_to_label)
memory_df['method'] = memory_df['method'].map(method_to_label)
# Create subplots

fig, axes = plt.subplots(1, 3, figsize=(14* cm, 5 * cm))
palette = sns.color_palette("muted")
ordered_labels = ['sylph profile',  'KMCP', 'ganon','Bracken', 'MetaPhlAn4']#, 'motus']
# Plot the wall time, CPU time and memory
ax1 = sns.barplot(y='time', x='method', log=True, data=time_df, estimator=lambda x: sum(x)/len(x), ax=axes[0], palette=palette, order=ordered_labels, ci=None)
ax2 = sns.barplot(y='cpu_time', x='method', log=True,  data=cpu_time_df, estimator=lambda x: sum(x)/len(x), ax=axes[1], palette=palette, order=ordered_labels, ci=None)
ax3 = sns.barplot(x='method', y='memory', data=memory_df, estimator=max, ax=axes[2], palette=palette, order=ordered_labels, ci=None)

ax1.set(xlabel='', ylabel= 'Mean wall time (s)')
ax2.set(xlabel='', ylabel='Mean CPU time (s)')
ax3.set(xlabel='', ylabel='Max memory (GB)')

# Add titles and remove top and right borders
titles = ['Mean wall Time (s)', 'Mean CPU Time (s)', 'Max Memory (GB)']
for ax, title in zip(axes, titles):
    #ax.set_title(title)
    sns.despine(ax=ax)

# Annotate bars with integers
for (k,ax) in enumerate(axes):
    for p in ax.patches:
        if p.get_height() < 10:
            test = round(p.get_height(),1)
        else:
            test = round(p.get_height())
        if k == 2:
            ax.annotate(f'{test}', (p.get_x() + p.get_width() / 2., p.get_height() + 2 ),
                    ha='center', va='bottom')
        else:
            ax.annotate(f'{test}', (p.get_x() + p.get_width() / 2., p.get_height() * 1.1 ),
                    ha='center', va='bottom')
    ax.tick_params(axis='x', rotation=75)

#plt.suptitle('Performance Metrics Across All Methods, Samples, and Experiments')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('figures/ani_profile_benchmark_times.svg')
plt.show()
# Out:
# /tmp/ipykernel_62886/1478278258.py:66: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax1 = sns.barplot(y='time', x='method', log=True, data=time_df, estimator=lambda x: sum(x)/len(x), ax=axes[0], palette=palette, order=ordered_labels, ci=None)
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /tmp/ipykernel_62886/1478278258.py:67: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax2 = sns.barplot(y='cpu_time', x='method', log=True,  data=cpu_time_df, estimator=lambda x: sum(x)/len(x), ax=axes[1], palette=palette, order=ordered_labels, ci=None)
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /tmp/ipykernel_62886/1478278258.py:68: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax3 = sns.barplot(x='method', y='memory', data=memory_df, estimator=max, ax=axes[2], palette=palette, order=ordered_labels, ci=None)
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/jimshawster/mambaforge/envs/taxprof/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up plot aesthetics
plt.rcParams.update({'font.size': 6})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family': 'arial'})

# Create the 1-row, 3-column subplot layout
fig, axes = plt.subplots(3, 2, figsize=(7 * cm, 12 * cm), sharey=True)
plt.subplots_adjust(hspace=0.4)
empty_stats = [[{'f1' : None, 'precision':None, 'sensitivity' :None, 'l1_constrain': None, 'l1genus': None}]]

# Define the test setups
test_setups = ["95-97.5% ANI (50 genomes) + \n85-90% ANI (150 genomes; not present at species-level)", 
               "95-97.5% ANI (200 genomes)",
               "97.5-99.9% ANI (200 genomes)"]

#methods = ['sylph profile', 'KMCP', 'Bracken\n0.01% cutoff']

# Loop through the test setups to fill the grid
for i, setup in enumerate(test_setups):
    #for (j, eval) in enumerate(['l1', 'l1_constrain']):
    for (j, eval) in enumerate(['l1_constrain', 'l1genus']):
        if i == 0:
            methods = ['sylph profile', 'KMCP', 'ganon', 'Bracken',' MetaPhlAn4']
            if j == 1:
                stats_l = [[sylph_stats_all,[],[]],
                           [kmcp_stats_all,[],[]], 
                           [ganon_stats_all,[],[]],
                           [kraken_stats_all,[],[]],
                           empty_stats]
            else:
                stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats, empty_stats]
        else:
            methods = ['sylph profile', 'KMCP', 'ganon', 'Bracken', 'MetaPhlAn4*']
            stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats, metaphlan_stats]
        ax = axes[i][j]
        
        # Extract the data for this subplot
        data_to_plot = []
        for k, method_stats in enumerate(stats_l):
            method_data = [x[eval] for x in method_stats[i]]
            data_to_plot.append(method_data)
        
        # Create the boxplot with smaller width
        sns.boxplot(data=data_to_plot, ax=ax, palette="muted", width=0.8)
        
        # Add labels
        # Two plots: species normalized L1, 
        # Holdout plot: species normalized L1, species true relative L1
        ax.set_xticklabels(methods)

        if j == 1:
            ax.set_title(test_setups[i], fontsize=7)
        
        if j == 1:
            ax.set_ylabel('L1 distance\n(all genus)')
        if j == 0:
            ax.set_ylabel('L1 distance\n(only present species)')
        if i != 2:
            ax.set_xticks([])
        # Remove the top and right borders
        sns.despine(ax=ax)
        ax.tick_params(axis='x', rotation=75)
        
# Show the grid of plots
#plt.tight_layout()
plt.savefig('figures/l1_metric_benchmark.svg')
plt.show()

# %%
def get_truth_skani(truth_file, ref_to_spec):
    truth = {}
    with open(truth_file, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            ref = row['Ref_file'].split('/')[-1]
            ref = ref.split('_genomic')[0][3:]
            spec = ref_to_spec[ref][1]
            #print(spec)
            truth[spec] = tax_result(spec, "", 0, 0)
    return truth
            

def read_sylph_meslier(file_path, ref_to_spec):
    sample_to_taxonomic_data = dict()
    sample_to_genus_data = dict()
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            query = row['Sample_file']
            exp = ""
            if 'illu' in query:
                exp = 'illu'
            elif 'nano' in query:
                exp = 'nano'
            elif 'pac' in query:
                exp = 'pac'
            else:
                print("exp not found", query)
            if exp in sample_to_taxonomic_data:
                taxonomic_data = sample_to_taxonomic_data[exp]
            else:
                taxonomic_data = {}
                sample_to_taxonomic_data[exp] = taxonomic_data
            if 'Query_file' in row:
                ref = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            else:
                ref = row['Genome_file'].split('/')[-1].split('_genomic')[0][3:]
            spec = ref_to_spec[ref]
            r = tax_result(spec[1],spec[0], float(row['Taxonomic_abundance'])/100, float(row['Sequence_abundance'])/100)
            taxonomic_data[spec[1]] = r
    for key,tax_data in sample_to_taxonomic_data.items():
        gen_data = {}
        for thing in tax_data.values():
            if thing.genus not in gen_data:
                gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
            else:
                gen_data[thing.genus].seq_abund += thing.seq_abund
        sample_to_genus_data[key] = gen_data
    return (sample_to_taxonomic_data, sample_to_genus_data)

(sylph_results,sylph_gen_results) = read_sylph_meslier('/mnt/disks/1tb/chng_meslier_simulated/sylph_out_meslier/sylph_output.tsv', ref_to_spec)
#(sylph_results,sylph_gen_results) = read_sylph('/mnt/disks/1tb/simulation_reads/sylph_results.tsv', ref_to_spec)

sylph_stats = dict()
kmcp_stats = dict()
ganon_stats = dict()
kraken_stats = dict()
metaphlan_stats = dict()
all_stats = []
exps = ['illu','nano','pac']

truth = f'/mnt/disks/1tb/chng_meslier_simulated/meslier_mock2-on_r89'
truth_data = get_truth_skani(truth,ref_to_spec)

for (i,exp) in enumerate(exps):
    if 'illu' == exp: 
        files = ['sylph',
             f'/mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/{exp}.kmcp.profile',
             f'/mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/{exp}.ganon.tre',
            f'/mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/{exp}_bracken_species.kreport',
            f'/mnt/disks/1tb/chng_meslier_simulated/metaphlan_out_meslier/{exp}.metaphlan.gtdb',
                ]
    elif 'nano' == exp:
        files = ['sylph',
             #f'/mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/{exp}.kmcp.profile',
            #f'/mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/{exp}.ganon.tre',
            f'/mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/{exp}_bracken_species.kreport',
                ]  
    else:
        files = ['sylph',
             f'/mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/{exp}.kmcp.profile',
             f'/mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/{exp}.ganon.tre',
            f'/mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/{exp}_bracken_species.kreport',
                ]  
    for result in files:
        gen_results = dict()
        #print(results)
        if 'ganon' in result:
            (results, gen_results) = read_ganon_file(result, species_name_to_spec, spec_to_metadata)
        elif 'sylph' in result:
            results = sylph_results[exp]
            #gen_results = sylph_gen_results[exp]
        elif 'kraken' in result:
            (results,gen_results) = read_kraken_file(result, species_name_to_spec, spec_to_metadata, 0.01)
        elif 'kmcp' in result:
            (results,gen_results) = read_kmcp_file(result, species_name_to_spec, spec_to_metadata)
        elif 'metaphlan' in result:
            (results,gen_results) = read_metaphlan(result, spec_to_metadata, r207_to_r89)

        debug = False
        if 'metaphlan' in result:
            debug = False
        stats = compare_to_truth(results, gen_results, truth_data, result, debug)
        all_stats.append((stats,exp,result))

    for stats,exp,result in all_stats:
        if 'sylph' in result:
            sylph_stats[exp] = stats
        if 'kmcp' in result:
            kmcp_stats[exp] = stats
        if 'ganon' in result:
            ganon_stats[exp] = stats
        if 'kraken' in result:
            kraken_stats[exp] = stats
        if 'metaphlan' in result:
            metaphlan_stats[exp] = stats

cm = 1/2.54  # centimeters in inches\n",
    ##Change this to get a bigger figure. \n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})

titles = ['Illumina','Illumina','Nanopore-old','Nanopore-old','PacBio', 'PacBio']
fig, axes = plt.subplots(1, 6, figsize=(16* cm, 5 * cm), sharey=True,gridspec_kw={'width_ratios': [5,5,2,2,4,4,]})
palette = sns.color_palette("muted")
#metric = 'precision'
for (i, exp) in enumerate(['illu', 'illu', 'nano', 'nano', 'pac', 'pac']):
    if i %2 == 0:
        metric = 'precision'
    else:
        metric = 'sensitivity'
    if exp == 'illu':
        ordered_labels = ['sylph profile',  'KMCP', 'Ganon', 'Bracken', 'MetaPhlAn4*']
        data = [[sylph_stats[exp][metric]], 
                [kmcp_stats[exp][metric]],
                [ganon_stats[exp][metric]],
                [kraken_stats[exp][metric]],
                [metaphlan_stats[exp][metric]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3], cmap[4]]
    elif exp == 'pac':
        ordered_labels = ['sylph profile', 'KMCP', 'Ganon', 'Bracken']
        data = [[sylph_stats[exp][metric]], [kmcp_stats[exp][metric]], [ganon_stats[exp][metric]], [kraken_stats[exp][metric]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3]]
    elif exp == 'nano':
        ordered_labels = ['sylph profile', 'Bracken']
        data = [[sylph_stats[exp][metric]], [kraken_stats[exp][metric]]]
        c = [cmap[0], cmap[3]]
    ax = sns.barplot(data = data, ax = axes[i], palette=c)
    ax.set_xticklabels(ordered_labels)
    ax.set_ylabel(metric.capitalize())
    #ax.set_title(titles[i])

    #ax.set_title(test_setups[i], fontsize=7)
    
    # Remove the top and right borders
    sns.despine(ax=ax)
    ax.tick_params(axis='x', rotation=75)

# Add this code to annotate with common titles
group_titles = ['Illumina', 'Nanopore-old', 'PacBio']
group_title_positions = [0.25, 0.565, 0.83]  # The x-position for each group title; adjust as needed

for title, pos in zip(group_titles, group_title_positions):
    fig.text(pos, 1.00, title, ha='center', va='bottom')
plt.savefig('figures/meslier_profiling.svg')
plt.show()
# Out:
# /tmp/ipykernel_62886/4180345161.py:363: RuntimeWarning: invalid value encountered in divide
#   norm_seq_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
# /tmp/ipykernel_62886/4180345161.py:365: RuntimeWarning: invalid value encountered in divide
#   genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
# /tmp/ipykernel_62886/4180345161.py:366: RuntimeWarning: invalid value encountered in divide
#   genus_seq_abund_vec_res = genus_seq_abund_vec_res / np.linalg.norm(genus_seq_abund_vec_res,1)
# /tmp/ipykernel_62886/4180345161.py:363: RuntimeWarning: divide by zero encountered in divide
#   norm_seq_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
# /tmp/ipykernel_62886/4180345161.py:365: RuntimeWarning: divide by zero encountered in divide
#   genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9461077844311379 1.000004 nan 0.9186046511627907 0.9753086419753086 81 79
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/illu.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.860759493670886 0.9999999999999994 nan 0.7906976744186046 0.9444444444444444 72 68
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/illu.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.935672514619883 1.0 nan 0.9302325581395349 0.9411764705882353 85 80
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/illu_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7885714285714287 1.0000000000000004 nan 0.8023255813953488 0.7752808988764045 89 69
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/metaphlan_out_meslier/illu.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.7848101265822784 0.9999999999999993 nan 0.7209302325581395 0.8611111111111112 72 62
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8108108108108107 1.0 nan 0.6976744186046512 0.967741935483871 62 60
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/nano_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8461538461538463 1.0000000000000004 nan 0.8953488372093024 0.8020833333333334 96 77
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.8774193548387097 0.9999979999999999 nan 0.7906976744186046 0.9855072463768116 69 68
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/pac.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.5172413793103449 0.9999999999999998 nan 0.3488372093023256 1.0 30 30
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/pac.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.9212121212121213 0.9999999999999999 nan 0.8837209302325582 0.9620253164556962 79 76
# ---------------    /mnt/disks/1tb/chng_meslier_simulated/kraken_out_meslier/pac_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct
# 0.759776536312849 1.0000000000000004 nan 0.7906976744186046 0.7311827956989247 93 68
