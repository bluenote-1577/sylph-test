# %% [markdown]
# # Set up and process metadata

# %%
import csv
import numpy as np
from dataclasses import dataclass
from sys import argv

def roc( res, genus_res, truth, filename, debug = False, genus=False):
    res = collapse_res(res)
    seq_abund_vec_res = []
    seq_abund_vec_truth = []

    sorted_res_vec = [(y.seq_abund,x) for x,y in res.items()] 
    sorted_res_vec.sort(reverse=True)
    sorted_gen_vec = [(y.seq_abund,x) for x,y in genus_res.items()] 
    sorted_gen_vec.sort(reverse=True)
    ret = []
    true_genera = set()
    for data in truth.values():
        true_genera.add(data.genus)
    print(len(true_genera), filename)
    if not genus:
        for i in range(len(sorted_res_vec)):
            vec = sorted_res_vec[0:len(sorted_res_vec)-i]
            r = dict()
            tp = 0
            fp = 0
            num_true = len(truth)
            num_pred = len(vec)
            for y,x in vec:
                r[x] = y
            for spec, data in truth.items():
                seq_abund_vec_truth.append(data.seq_abund)
                if spec in r:
                    #if debug:
                    #    print(truth[spec], res[spec])
                    tp += 1
                else:
                    if debug:
                        print(spec, data)
                    #fp += 1
            for spec, data in r.items():
                if spec not in truth:
                    if debug:
                        print(data)
                    fp += 1
            ret.append((tp/len(truth), 1 - fp/len(vec)))
    else:
        for i in range(len(sorted_gen_vec)):
            gen_vec = sorted_gen_vec[0:len(sorted_gen_vec)-i]
            gen_vec = dict([(y,x) for x,y in gen_vec])
            tp_gen = 0
            fp_gen = 0
            ###--- genus resultrs
            for gen, _ in gen_vec.items():
                if gen not in true_genera:
                    fp_gen += 1
                else:
                    tp_gen += 1
            ret.append((tp_gen/len(true_genera), 1 - fp_gen/len(gen_vec)))

    return ret

def normalize(results, spec_to_metadata = None):
    total = 0
    if spec_to_metadata:
        for key,thing in results.items():
            size = float(spec_to_metadata[key]['genome_size'])
            total += size * thing.seq_abund
        for key, thing in results.items():
            size = float(spec_to_metadata[key]['genome_size'])
            thing.seq_abund = thing.seq_abund * size / total
    else:
        for thing in results.values():
            total += thing.seq_abund 
        for thing in results.values():
            thing.seq_abund = thing.seq_abund/total

@dataclass
class tax_result:
    species: str
    genus: str
    abund: float
    seq_abund: float

@dataclass
class gen_abund:
    genus: str
    seq_abund: float

def get_spec_to_metadata(file_path, ganon_input):
    used_genomes = set()
    with open(ganon_input,'r') as f:
        for line in f:
            used = line.split('\t')[0].split('/')[-1].split('.fa')[0]
            used_genomes.add(used)
    spec_to_metadata = {}
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            if row['accession'] in used_genomes:
                spec = row['gtdb_taxonomy'].split(';')[-1]
                spec_to_metadata[spec] = row
            # if row['gtdb_representative'] == 'y':
            #     spec = row['gtdb_taxonomy'].split(';')[-1]
            #     spec_to_metadata[spec] = row
            # elif row['gtdb_taxonomy'].split(';')[-1] not in spec_to_metadata:
            #     spec = row['gtdb_taxonomy'].split(';')[-1]
            #     spec_to_metadata[spec] = row
    return spec_to_metadata

def read_ganon_file(file_path, species_name_to_spec_and_genus, spec_to_metadata):
    taxonomic_data = {}
    gen_data  = {}
    with open(file_path, 'r') as f:
        for line in f:
            spl = line.split('\t')
            if spl[0] == 'species':
                name = spl[3]
                num_seqs = float(spl[-2])
                spec = species_name_to_spec_and_genus[name]
                species = spec[1]
                genus = spec[0]
                abund = 0
                seq_abund = num_seqs
                taxonomic_data[species] = tax_result(species, genus, abund, seq_abund)
            if spl[0] == 'genus':
                num_seqs = float(spl[-2])
                genus = f"g__{spl[3]}"
                gen_data[genus] = gen_abund(genus,num_seqs)
                
    normalize(taxonomic_data)
    normalize(gen_data)
    return (taxonomic_data, gen_data)

def read_kraken_file(file_path, species_name_to_spec_and_genus, spec_to_metadata, cutoff):
    tax_data = {}
    gen_data = {}
    with open(file_path, 'r') as f:
        for row in f:
            spl = row.split('\t')
            if spl[3] == 'S':
                spec = spl[-1].strip()
                species = species_name_to_spec_and_genus[spec][1]
                seq_abund = float(spl[0])
                if seq_abund > cutoff:
                    res = tax_result(species, 'NA', 0, seq_abund)
                    tax_data[species] = res
            if spl[3] == 'G':
                ab = float(spl[0])
                if ab > cutoff:
                    genus = f"g__{spl[-1].strip()}"
                    gen_data[genus] = gen_abund(genus,float(spl[0]))

    normalize(tax_data)
    normalize(gen_data)
    return (tax_data,gen_data)  

def read_kmcp_file(file_path, species_name_to_spec_and_genus, spec_to_metadata):
    tax_data = {}
    gen_data = {}
    with open(file_path, 'r') as f:
        for row in f:
            if '@' in row:
                continue
            spl = row.split('\t')
            if spl[1] == 'species':
                spec = spl[3].split('|')[-1].rstrip()
                species = species_name_to_spec_and_genus[spec][1]
                genus = species_name_to_spec_and_genus[spec][0]
                seq_abund = float(spl[-1].rstrip())
                res = tax_result(species, genus, 0, seq_abund)
                tax_data[species] = res
            if spl[1] == 'genus':
                genus = spl[3].split('|')[-1].rstrip()
                genus = f"g__{genus}"
                #gen_data[genus] = gen_abund(genus,float(spl[-1].rstrip()))

    normalize(gen_data)
    normalize(tax_data, spec_to_metadata)
    gen_data = {}
    for thing in tax_data.values():
        if thing.genus not in gen_data:
            gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
        else:
            gen_data[thing.genus].seq_abund += thing.seq_abund
    normalize(gen_data)
    return (tax_data, gen_data)   
    
def read_bac_to_gtdb(file_path):
    ref_to_spec_and_genus = {}
    species_name_to_spec_and_genus = {}
    with open(file_path, 'r') as f:
        for line in f:
            spl = line.strip().split("\t")
            ref = spl[0][3:]
            spec_and_genus = spl[1].split(';')[-2:]
            ref_to_spec_and_genus[ref] = spec_and_genus
            spec_string = spl[1].split(';')[-1][3:]
            species_name_to_spec_and_genus[spec_string] = spec_and_genus
    return (ref_to_spec_and_genus,species_name_to_spec_and_genus)

def truth(file_path, spec_to_metadata, spec90 = False):
    taxonomic_data = dict()
    results = []
    with open(file_path, 'r') as f:
        csv_reader = csv.reader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            spec = spl[0].split(';')[-2:]
            seq_abund = float(spl[1])
            size = float(spec_to_metadata[spec[1]]['genome_size'])
            data = tax_result(spec[1], spec[0], size, seq_abund)
            if spec90:
                if len(results) >= 50:
                    break
            results.append(data)
    total_cov = 0
    total_seq = 0
    for r in results:
        total_cov += r.abund * r.seq_abund
        total_seq += r.seq_abund
    for r in results:
        r.abund = r.abund * r.seq_abund / total_cov
        #r.seq_abund = r.seq_abund / total_seq
        if r.species in taxonomic_data:
            #print(r.species)
            taxonomic_data[r.species].seq_abund += r.seq_abund 
            taxonomic_data[r.species].abund += r.abund 
        else:
            taxonomic_data[r.species] = r

    return taxonomic_data

def read_sylph(file_path, ref_to_spec):
    sample_to_taxonomic_data = dict()
    sample_to_genus_data = dict()
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            query = row['Sample_file'].split('/')[-1].split('_')
            diff = int(query[0][-2:])
            it = int(query[1])
            if (diff,it) in sample_to_taxonomic_data:
                taxonomic_data = sample_to_taxonomic_data[(diff,it)]
            else:
                taxonomic_data = {}
                sample_to_taxonomic_data[(diff,it)] = taxonomic_data
            if 'Query_file' in row:
                ref = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            else:
                ref = row['Genome_file'].split('/')[-1].split('_genomic')[0][3:]
            spec = ref_to_spec[ref]
            r = tax_result(spec[1],spec[0], float(row['Taxonomic_abundance'])/100, float(row['Sequence_abundance'])/100)
            taxonomic_data[spec[1]] = r
    for key,tax_data in sample_to_taxonomic_data.items():
        gen_data = {}
        for thing in tax_data.values():
            if thing.genus not in gen_data:
                gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
            else:
                gen_data[thing.genus].seq_abund += thing.seq_abund
        sample_to_genus_data[key] = gen_data
    return (sample_to_taxonomic_data, sample_to_genus_data)

def read_metaphlan(file_path, spec_to_metadata, r207_to_r89):
    taxonomic_data = dict()
    results = []
    with open(file_path, 'r') as f:
        for row in f:
            if 's__' in row:
                spl = row.split('\t')[0].split(';')[-2:]
                genus = spl[0]
                spec = spl[1]
                key = tuple([genus, spec])
                if key not in r207_to_r89:
                    print(spec)
                    continue
                r89 = r207_to_r89[key]
                r89_spec = r89[1]
                r89_genus = r89[0]
                abund = row.split('\t')[-1].rstrip()
                size = spec_to_metadata[r89_spec]['genome_size']
                data = tax_result(r89_spec, r89_genus, float(abund), float(abund))
                taxonomic_data[r89_spec] = data
            # if 'g__' in row.split('\t')[0].split(';')[-1]:
            #     spl = row.split('\t')[0].split(';')[-2:]
            #     genus = spl[0]
            #     spec = spl[1]
            #     key = tuple([genus, spec])
            #     if key not in r207_to_r89:
            #         print(spec)
            #         continue
            #     r89 = r207_to_r89[key]
            #     r89_genus = r89[0]
            #     abund = row.split('\t')[-1].rstrip()
            #     data = gen_abund(r89_genus, float(abund))
            #     gen_data[r89_genus] = data


    normalize(taxonomic_data, spec_to_metadata)
    #normalize(taxonomic_data)
    gen_data = {}
    for thing in taxonomic_data.values():
        if thing.genus not in gen_data:
            gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
        else:
            gen_data[thing.genus].seq_abund += thing.seq_abund
    normalize(gen_data)
    return(taxonomic_data, gen_data)

def collapse_res(res):
    new_res = defaultdict(float)
    for key,value in res.items():
        if key in new_res:
            new_res[key].seq_abund += value.seq_abund
            new_res[key].abund += value.abund
        else:
            new_res[key] = value
    return new_res
    
def compare_to_truth( res, genus_res, truth, filename, debug = False):
    res = collapse_res(res)
    genus_res = collapse_res(genus_res)
    tp = 0
    fp = 0
    num_true = len(truth)
    num_pred = len(res)
    seq_abund_vec_res = []
    seq_abund_vec_truth = []

    genus_seq_abund_vec_res = []
    genus_seq_abund_vec_truth = []

    genus_to_abund_truth = dict()
    genus_to_abund_res = dict()

    true_genera = set()
    for data in genus_res.values():
        if data.genus not in genus_to_abund_res:
            genus_to_abund_res[data.genus] = data.seq_abund
        else:
            genus_to_abund_res[data.genus] += data.seq_abund
            
    for data in truth.values():
        true_genera.add(data.genus)
        if data.genus not in genus_to_abund_truth:
            genus_to_abund_truth[data.genus] = data.seq_abund
        else:
            genus_to_abund_truth[data.genus] += data.seq_abund        

    for (genus, abund) in genus_to_abund_truth.items():
        if genus not in genus_to_abund_res:
            genus_seq_abund_vec_truth.append(abund)
            genus_seq_abund_vec_res.append(0)
        else:
            genus_seq_abund_vec_truth.append(abund)
            genus_seq_abund_vec_res.append(genus_to_abund_res[genus])
    for (genus,abund) in genus_to_abund_res.items():
        if genus not in genus_to_abund_truth:
            genus_seq_abund_vec_res.append(abund)
            genus_seq_abund_vec_truth.append(0)

    for spec, data in truth.items():
        seq_abund_vec_truth.append(data.seq_abund)
        if spec in res:
            #if debug:
            #    print(truth[spec], res[spec])
            seq_abund_vec_res.append(res[spec].seq_abund)
            tp += 1
        else:
            if debug:
                print(spec, data)
            seq_abund_vec_res.append(0)
            #fp += 1
    for spec, data in res.items():
        if spec not in truth:
            if debug:
                print(data)
            fp += 1
            seq_abund_vec_res.append(res[spec].seq_abund)
            seq_abund_vec_truth.append(0)
    tp_gen = 0
    fp_gen = 0
    ###--- genus resultrs
    for gen, data in genus_res.items():
        if gen not in true_genera:
            fp_gen += 1
        else:
            tp_gen += 1

    num_true_gen = len(true_genera)
    num_pred_gen = fp_gen + tp_gen
    ####
    #seq_abund_vec_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
    #seq_abund_vec_res = seq_abund_vec_res / np.linalg.norm(seq_abund_vec_res,1)
    #genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
    #genus_seq_abund_vec_res = genus_seq_abund_vec_res / np.linalg.norm(genus_seq_abund_vec_res,1)


    norm_seq_truth = seq_abund_vec_truth / np.linalg.norm(seq_abund_vec_truth,1)
    norm_seq_res = seq_abund_vec_res / np.linalg.norm(seq_abund_vec_res,1)
    genus_seq_abund_vec_truth = genus_seq_abund_vec_truth / np.linalg.norm(genus_seq_abund_vec_truth, 1)
    genus_seq_abund_vec_res = genus_seq_abund_vec_res / np.linalg.norm(genus_seq_abund_vec_res,1)
    
    l1_seqabund = np.sum(np.abs(np.array(seq_abund_vec_res) - np.array(seq_abund_vec_truth)))
    l1_genus_seqabund = np.sum(np.abs(np.array(genus_seq_abund_vec_truth) - np.array(genus_seq_abund_vec_res)))

    l1_seqabund_species = (np.sum(np.abs(np.array(norm_seq_truth) - np.array(norm_seq_res))))

    sensitivity = tp/num_true
    precision = 1 - fp/num_pred

    if num_true_gen == 0:
        num_true_gen = 0.5
    if num_pred_gen == 0:
        num_pred_gen = 0.5
    sens_gen = tp_gen/num_true_gen 
    prec_gen = 1 - fp_gen/num_pred_gen 
    if sens_gen == 0:
        sens_gen = 1
    if prec_gen == 0:
        prec_gen = 1
    print('---------------    ' + filename)
    print("F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp")
    f1 = 2 / (1 / sensitivity + 1 / precision)
    f1_gen = 2 / (1 / sens_gen  + 1 / prec_gen)
    print(f1, l1_seqabund, l1_genus_seqabund, sensitivity, precision, num_pred, tp, fp)
    return({"f1":f1, "l1":l1_seqabund, "sensitivity": sensitivity, "precision": precision,
            "num_pred": num_pred, "tp": tp, "l1genus": l1_genus_seqabund, "l1_constrain": l1_seqabund_species,
          "precision genus":prec_gen, "sensitivity genus":sens_gen, "f1 genus": f1_gen})

# %%
def get_r207_to_r89(skani_file, r89_meta, r207_meta):

    # Initialize an empty dictionary to store the mapping from accession to gtdb_taxonomy
    accession_to_taxonomy_r89 = {}
    
    # Read the TSV file
    with open(r89_meta, mode='r') as f:
        tsv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in tsv_reader:
            accession = row['accession'][3:]
            taxonomy = tuple(row['gtdb_taxonomy'].split(';')[-2:])
            accession_to_taxonomy_r89[accession] = taxonomy

    # Initialize an empty dictionary to store the mapping from accession to gtdb_taxonomy
    accession_to_taxonomy_r207 = {}
    
    # Read the TSV file
    with open(r207_meta, mode='r') as f:
        tsv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in tsv_reader:
            accession = row['accession'][3:]
            taxonomy = tuple(row['gtdb_taxonomy'].split(';')[-2:])
            accession_to_taxonomy_r207[accession] = taxonomy
    # Initialize an empty dictionary to store the Ref_file as th
    # Initialize an empty dictionary to store the Ref_file as the key and the Query_file with the highest ANI as the value
    highest_ani_dict = {}
    
    # Read the CSV file
    with open(skani_file, mode='r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')  # Assuming the file is tab-separated
        for row in csv_reader:
            # Extract relevant parts of the filename to create keys and values in the form "GCA_000182945.1"
            ref_key = row['Ref_file'].split('/')[-1].split('_genomic')[0]
            query_key = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            
            # Convert ANI to float for comparison
            ani = float(row['ANI'])
            
            # Update the dictionary
            if ref_key not in highest_ani_dict or ani > highest_ani_dict[ref_key]['ANI']:
                highest_ani_dict[ref_key] = {'Query': query_key, 'ANI': ani}

    ret = {}
    for key,value in highest_ani_dict.items():
        if value['ANI'] > 93:
            r207_tax = accession_to_taxonomy_r207[key]
            r89_tax = accession_to_taxonomy_r89[value['Query']]
            ret[r207_tax] = r89_tax
    return ret

## YOU WILL HAVE TO UNGZIP the files if download from github
r207_to_r89 = get_r207_to_r89('profile_results/r89-to-r207.tsv', 
                              'profile_results/combined_metadata_r89.tsv', 
                              'profile_results/combined_metadata_r207.tsv')

spec_to_metadata = get_spec_to_metadata('profile_results/combined_metadata_r89.tsv', 'profile_results/ganon-input.tsv')
(ref_to_spec,species_name_to_spec) = read_bac_to_gtdb('profile_results/gtdb_combined_r89_taxonomy.tsv')

# %%
(sylph_results,sylph_gen_results) = read_sylph('profile_results/sylph_output.tsv', ref_to_spec)

from collections import defaultdict
all_stats = [[],[],[]] 
all_rocs = [[],[],[]]
sylph_stats = [[],[],[]]
kmcp_stats = [[],[],[]]
ganon_stats = [[],[],[]]
kraken_stats = [[],[],[]]
metaphlan_stats = [[],[],[]]

sylph_rocs = [[],[],[]]
kmcp_rocs = [[],[],[]]
ganon_rocs = [[],[],[]]
kraken_rocs = [[],[],[]]
metaphlan_rocs = [[],[],[]]

sylph_stats_all = []
kmcp_stats_all = []
ganon_stats_all = []
kraken_stats_all = []
metaphlan_stats_all = []
kraken_cutoff = 0.01
roc_genus = False
exps = [90]
its = range(1,11)

#exps = [98]
#its = [5,7]
for (i,diff) in enumerate(exps):
    for it in its:
        files = [' ', f'profile_results/species{diff}_{it}.tsv',
               'sylph',
             f'profile_results/species{diff}_{it}.kmcp.profile',
             f'profile_results/species{diff}_{it}.ganon.tre',
            f'profile_results/species{diff}_{it}_bracken_species.kreport',
            f'profile_results/species{diff}_{it}.metaphlan.gtdb',
              ]
        if diff == 90:
            truth_data = truth(files[1], spec_to_metadata, spec90 = True)
            truth_data_all = truth(files[1],spec_to_metadata, spec90=False)
        else:
            truth_data = truth(files[1], spec_to_metadata)
        # Test the functions
        files = files[2:]
        
        print(it,diff)
        for result in files:
            print(result)
            gen_results = None
            if 'ganon' in result:
                (results, gen_results) = read_ganon_file(result, species_name_to_spec, spec_to_metadata)
            elif 'sylph' in result:
                results = sylph_results[(diff,it)]
                gen_results = sylph_gen_results[(diff,it)]
            elif 'ken' in result:
                (results,gen_results) = read_kraken_file(result, species_name_to_spec, spec_to_metadata, kraken_cutoff)
                #compare_to_truth(results, truth_data)
                #results = read_kraken_file(result, species_name_to_spec, spec_to_metadata, 0.01 / 100)
            elif 'kmcp' in result:
                (results,gen_results) = read_kmcp_file(result, species_name_to_spec, spec_to_metadata)
            elif 'metaphlan' in result:
                (results,gen_results) = read_metaphlan(result, spec_to_metadata, r207_to_r89)

            debug = False
            if 'metaphlan' in result:
                debug = False
            stats = compare_to_truth(results, gen_results, truth_data, result, debug)
            all_stats[i].append((stats,diff,it, result))
            if not roc_genus:
                all_rocs[i].append((roc(results,gen_results,truth_data,result,debug,genus=roc_genus), diff, it, result))  
            if diff == 90:
                if roc_genus:
                    all_rocs[i].append((roc(results,gen_results,truth_data_all,result,debug,genus=roc_genus), diff, it, result))
                bad_stats = compare_to_truth(results, gen_results, truth_data_all,result, debug)
                if 'sylph' in result:
                    sylph_stats_all.append(bad_stats)
                if 'kmcp' in result:
                    kmcp_stats_all.append(bad_stats)
                if 'ganon' in result:
                    ganon_stats_all.append(bad_stats)
                if 'ken' in result:
                    kraken_stats_all.append(bad_stats)
                if 'metaphlan' in result:
                    metaphlan_stats_all.append(bad_stats)

    for stats,diff,it,result in all_stats[i]:
        if 'sylph' in result:
            sylph_stats[i].append(stats)
        if 'kmcp' in result:
            kmcp_stats[i].append(stats)
        if 'ganon' in result:
            ganon_stats[i].append(stats)
        if 'ken' in result:
            kraken_stats[i].append(stats)
        if 'metaphlan' in result:
            metaphlan_stats[i].append(stats)

    for stats,diff,it,result in all_rocs[i]:
        if 'sylph' in result:
            sylph_rocs[i].append(stats)
        if 'kmcp' in result:
            kmcp_rocs[i].append(stats)
        if 'ganon' in result:
            ganon_rocs[i].append(stats)
        if 'ken' in result:
            kraken_rocs[i].append(stats)
        if 'metaphlan' in result:
            metaphlan_rocs[i].append(stats)
# Out:
# 1 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8043478260869565 0.6340576761828084 0.22991348599496275 0.74 0.8809523809523809 42 37 5
# 42 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3096234309623431 1.1568132623917924 1.1315566054492772 0.18781725888324874 0.8809523809523809 42 37 5
# profile_results/species90_1.kmcp.profile
# ---------------    profile_results/species90_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6190476190476191 0.5336473126050111 0.21662012028641123 0.78 0.513157894736842 76 39 37
# 42 profile_results/species90_1.kmcp.profile
# ---------------    profile_results/species90_1.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3516483516483517 1.041763897181931 1.0038221612191425 0.2436548223350254 0.631578947368421 76 48 28
# profile_results/species90_1.ganon.tre
# ---------------    profile_results/species90_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.49557522123893805 0.6932825182669301 0.6638414662459927 0.56 0.4444444444444444 63 28 35
# 42 profile_results/species90_1.ganon.tre
# ---------------    profile_results/species90_1.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.25384615384615383 1.209351466544061 1.080035034431641 0.16751269035532995 0.5238095238095238 63 33 30
# profile_results/species90_1_bracken_species.kreport
# ---------------    profile_results/species90_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.13714285714285712 0.5624329694724188 0.8714488898433534 0.72 0.07578947368421052 475 36 439
# 42 profile_results/species90_1_bracken_species.kreport
# ---------------    profile_results/species90_1_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.375 0.6983512744781886 0.3398064892247338 0.6395939086294417 0.26526315789473687 475 126 349
# profile_results/species90_1.metaphlan.gtdb
# s__Microvirga sp016427565
# s__Methylosinus sp009811655
# s__Methylophilus sp015354345
# s__Mesorhizobium silamurunense
# s__Dysosmobacter excrementavium
# s__CAG-302 sp900548425
# s__Pseudomonas_E sp012935695
# s__Pseudomonas_S boreopolis
# s__Vagococcus hydrophili
# s__
# s__Desulfovibrio legallii
# s__Leptospira stimsonii_A
# s__Thermosynechococcus elongatus_B
# s__Sandaracinobacter neustonicus
# s__Blastococcus sp004571075
# s__Aeromicrobium fastidiosum
# s__Sulfuritortus calidifontis
# s__Gemmiger sp900545545
# s__Buttiauxella warmboldiae
# s__Brasilonema octagenarum
# s__Blastococcus colisei
# s__Kineococcus aurantiacus
# s__Rhodomicrobium lacus
# s__Mucilaginibacter ginsenosidivorax
# s__Desulfobacter latus
# s__CAG-170 sp900553545
# s__Arthrobacter_B gandavensis_A
# s__Duganella alba
# s__Microbacterium hydrothermale
# s__Rhodoglobus sp015864955
# s__Saccharofermentans sp902764825
# s__Planobispora siamensis
# s__UBA10677 sp900762945
# s__Bartonella massiliensis
# s__Sphingobacterium detergens
# s__Microbacterium sp018613995
# s__Flavobacterium anhuiense_B
# s__Nocardia rhizosphaerihabitans
# s__Halobacillus faecis
# s__
# s__Hymenobacter perfusus
# s__Pseudoxanthomonas_A sp014852005
# s__Nocardioides sp016735675
# s__Cupriavidus pauculus_C
# s__Protaetiibacter sp014483895
# s__Halomonas stenophila
# s__Micromonospora qiuiae
# s__D2472 sp902511575
# s__Fibrisoma montanum
# s__Streptomyces ferrugineus
# s__Rhodococcus_B sp017168335
# s__Paenibacillus tritici
# s__CAG-83 sp900549395
# s__Aeromicrobium piscarium
# s__Chromobacterium phragmitis
# s__Muricauda sp011068285
# s__Pseudomonas_E sp902506505
# ---------------    profile_results/species90_1.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6194690265486725 0.5623242411107826 0.1492136588147362 0.7 0.5555555555555556 63 35 28
# 42 profile_results/species90_1.metaphlan.gtdb
# ---------------    profile_results/species90_1.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.41538461538461535 1.0597551041641742 1.0180905133417228 0.27411167512690354 0.8571428571428572 63 54 9
# 2 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8478260869565218 0.6263306429054387 0.1090774966050514 0.78 0.9285714285714286 42 39 3
# 42 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.32911392405063294 1.2117206573360395 1.1762536826742833 0.2 0.9285714285714286 42 39 3
# profile_results/species90_2.kmcp.profile
# ---------------    profile_results/species90_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5517241379310345 1.251566022923941 1.4996850027584843 0.64 0.48484848484848486 66 32 34
# 42 profile_results/species90_2.kmcp.profile
# ---------------    profile_results/species90_2.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3371647509578544 1.6432413915143433 1.4935918538726871 0.22564102564102564 0.6666666666666667 66 44 22
# profile_results/species90_2.ganon.tre
# ---------------    profile_results/species90_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5283018867924528 0.6049169584399867 0.6412419211796202 0.56 0.5 56 28 28
# 42 profile_results/species90_2.ganon.tre
# ---------------    profile_results/species90_2.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.26294820717131473 1.1541650376226031 1.0176890165715577 0.16923076923076924 0.5892857142857143 56 33 23
# profile_results/species90_2_bracken_species.kreport
# ---------------    profile_results/species90_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.20460358056265984 0.6997724668009437 0.9005777313960143 0.8 0.11730205278592376 341 40 301
# 42 profile_results/species90_2_bracken_species.kreport
# ---------------    profile_results/species90_2_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.4626865671641791 0.7509713292293501 0.34302237806089314 0.6358974358974359 0.36363636363636365 341 124 217
# profile_results/species90_2.metaphlan.gtdb
# s__Halarchaeum rubridurum
# s__Prolixibacter sp009617895
# s__Cryptobacteroides sp902785825
# s__Alteromonas macleodii_A
# s__Winogradskyella helgolandensis
# s__Cytobacillus sp018613035
# s__Thermomonospora amylolytica
# s__Chromohalobacter marismortui
# s__Flavobacterium microcysteis
# s__Cryobacterium sp004403465
# s__Nitrosotenuis sp016872055
# s__Streptococcus zalophi
# s__Stomatobaculum longum_A
# s__Mucilaginibacter rigui
# s__QAMH01 sp900544245
# s__Gemmobacter_B sp009908315
# s__
# s__Gemmatimonas sp013004105
# s__Agromyces salentinus
# s__Rippkaea sp003574135
# s__Leifsonia shinshuensis
# s__Pelomonas saccharophila
# s__Pseudarthrobacter sp006715285
# s__Pseudomonas_E leptonychotis
# s__Clostridium_AM sp012926525
# s__Dysosmobacter excrementavium
# s__Pelagibacter sp014653585
# s__Pseudomonas_E mosselii_C
# s__GCA-2697345 sp905181985
# s__Pseudomonas_E sp013359595
# s__Pseudomonas_E chlororaphis_G
# s__Paracoccus aerius
# s__Paracoccus lichenicola
# s__Tolumonas osonensis
# s__Rhizobium lusitanum_B
# s__Pseudomonas_E cichorii_B
# s__Agromyces sp008122505
# s__Methylobacterium crusticola
# s__Pseudoduganella plicata
# s__Streptomyces echinoruber
# s__Actinoplanes sp004001265
# s__CAG-302 sp900548425
# s__Massilia sp011682055
# s__Stenotrophomonas tumulicola
# s__
# s__Mangrovicoccus sp013184745
# s__Thermococcus stetteri
# s__
# s__Streptomyces fumanus
# s__Halosimplex litoreum
# s__Duganella sp009857435
# s__Chryseobacterium bernardetii
# s__
# s__Pseudomonas_E sp004353925
# s__Bradyrhizobium diazoefficiens_C
# s__
# s__
# s__Flavobacterium sp902506345
# s__Malaciobacter sp004116495
# ---------------    profile_results/species90_2.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5576923076923077 0.6889742394575279 0.2222494148799204 0.58 0.537037037037037 54 29 25
# 42 profile_results/species90_2.metaphlan.gtdb
# ---------------    profile_results/species90_2.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.35341365461847396 1.2383056845216143 1.1580602718066255 0.22564102564102564 0.8148148148148149 54 44 10
# 3 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8695652173913044 0.7906580425584112 0.10305672509000542 0.8 0.9523809523809523 42 40 2
# 42 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.33613445378151263 1.575428037670934 1.420701370095283 0.20408163265306123 0.9523809523809523 42 40 2
# profile_results/species90_3.kmcp.profile
# ---------------    profile_results/species90_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5581395348837209 0.85439523615146 0.43717496044465065 0.72 0.45569620253164556 79 36 43
# 42 profile_results/species90_3.kmcp.profile
# ---------------    profile_results/species90_3.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.4 1.423139431288618 1.2406685177917178 0.28061224489795916 0.6962025316455696 79 55 24
# profile_results/species90_3.ganon.tre
# ---------------    profile_results/species90_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5405405405405405 0.8059264726000156 0.6317703398809673 0.6 0.4918032786885246 61 30 31
# 42 profile_results/species90_3.ganon.tre
# ---------------    profile_results/species90_3.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.34241245136186776 1.3835819668946625 1.2255672781635945 0.22448979591836735 0.7213114754098361 61 44 17
# profile_results/species90_3_bracken_species.kreport
# ---------------    profile_results/species90_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.13120000000000004 0.8555885373704486 1.272259484770883 0.82 0.07130434782608697 575 41 534
# 42 profile_results/species90_3_bracken_species.kreport
# ---------------    profile_results/species90_3_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.35019455252918286 0.8804031199025609 0.31602940811917246 0.6887755102040817 0.23478260869565215 575 135 440
# profile_results/species90_3.metaphlan.gtdb
# s__Pontibacter amylolyticus
# s__Halomonas sp902500215
# s__GN02-872 sp002761215
# s__Erwinia sp003937915
# s__Polynucleobacter sp018688355
# s__Psychrobacter immobilis_E
# s__Blattabacterium cuenoti_G
# s__
# s__Blautia sp900753905
# s__Nocardioides salarius
# s__Gillisia mitskevichiae
# s__Acinetobacter pollinis
# s__Pelagibacter sp902597335
# s__Buchnera aphidicola_AP
# s__Nocardioides panzhihuensis
# s__Kushneria pakistanensis
# s__Tersicoccus solisilvae
# s__CAG-533 sp900553855
# s__Neisseria potus
# s__Dialister sp900538805
# s__Gemmiger sp900540775
# s__Acetatifactor sp900772845
# s__Cloacibacterium rupense
# s__Pseudarthrobacter sp902506025
# s__YY08-10 sp016629565
# s__Pseudomonas_E sp016650815
# s__Streptomyces brasiliensis
# s__Azohydromonas caseinilytica
# s__
# s__Elioraea sp006704265
# s__Coprenecus sp900550465
# s__
# s__Amycolatopsis bartoniae
# s__Bradyrhizobium archetypum
# s__Arachnia sp013333945
# s__UBA1723 sp015061115
# s__Streptomyces olivoreticuli
# s__Sphingobium sp013375555
# s__Streptacidiphilus sp014084125
# s__Flavobacterium sp004151275
# s__Pseudomonas_E alcaligenes_C
# s__Actinosynnema algeriensis
# s__Lysobacter sp015209725
# s__Frigoribacterium sp017833035
# s__Pseudarthrobacter sp018613675
# s__GCA-2697345 sp905181985
# s__Methylobacterium crusticola
# s__Listeria kieliensis_A
# s__Streptomyces piniterrae
# s__Aliarcobacter suis
# s__Nonomuraea sp008017515
# s__Halomonas sp009834345
# s__Pararheinheimera sp003990335
# s__Roseomonas nepalensis
# s__Spirillospora sp004349245
# s__Hahella sp004135205
# s__
# s__
# s__Sphingomonas sp007833215
# s__Sulfurimonas crateris
# s__Chryseobacterium sp003385515
# s__Brevibacterium aurantiacum_A
# s__Companilactobacillus huachuanensis
# s__Agrococcus jenensis
# s__Microvirga sp018383585
# ---------------    profile_results/species90_3.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5925925925925926 0.9448697589323163 0.6927643680724875 0.64 0.5517241379310345 58 32 26
# 42 profile_results/species90_3.metaphlan.gtdb
# ---------------    profile_results/species90_3.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.37795275590551186 1.6379999889694008 1.5076089608054768 0.24489795918367346 0.8275862068965517 58 48 10
# 4 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.7912087912087913 0.849929340566186 0.06770374050556179 0.72 0.8780487804878049 41 36 5
# 43 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.30379746835443044 1.6882128255476243 1.575976811425435 0.1836734693877551 0.8780487804878049 41 36 5
# profile_results/species90_4.kmcp.profile
# ---------------    profile_results/species90_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.510948905109489 0.8675760583499086 0.3345207456399878 0.7 0.4022988505747126 87 35 52
# 43 profile_results/species90_4.kmcp.profile
# ---------------    profile_results/species90_4.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.36042402826855124 1.527665097982738 1.4165795646458221 0.2602040816326531 0.5862068965517242 87 51 36
# profile_results/species90_4.ganon.tre
# ---------------    profile_results/species90_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.4444444444444444 0.8583262998249686 0.5847458995591891 0.48 0.4137931034482759 58 24 34
# 43 profile_results/species90_4.ganon.tre
# ---------------    profile_results/species90_4.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.26771653543307083 1.5486254145198612 1.2481580533246144 0.17346938775510204 0.5862068965517242 58 34 24
# profile_results/species90_4_bracken_species.kreport
# ---------------    profile_results/species90_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.14205607476635523 0.8575844449986241 1.4337012167824672 0.76 0.07835051546391758 485 38 447
# 43 profile_results/species90_4_bracken_species.kreport
# ---------------    profile_results/species90_4_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3935389133627019 0.913069588483981 0.3202328444351388 0.6836734693877551 0.27628865979381445 485 134 351
# profile_results/species90_4.metaphlan.gtdb
# s__Blastococcus sp004570425
# s__Blattabacterium cuenoti_Q
# s__Ventrimonas sp003480315
# s__Beduini sp902363625
# s__Flavobacterium sp009792295
# s__Mycobacterium sp011745145
# s__Cyanobacterium stanieri_B
# s__
# s__Tenacibaculum gallaicum
# s__Holdemanella sp003458715
# s__Kitasatospora kifunensis
# s__Spiroplasma_A sp010365805
# s__Jiangella ureilytica
# s__Kiloniella sp900313065
# s__Conexibacter arvalis
# s__Hymenobacter perfusus
# s__Microbacterium hibisci
# s__Chryseobacterium cheonjiense
# s__UBA738 sp900763675
# s__Streptosporangium sandarakinum
# s__Tepidimonas alkaliphilus
# s__Nocardia yunnanensis
# s__CAG-127 sp900767585
# s__Peptoniphilus_A gorbachii
# s__Scalindua sp018648405
# s__Sphingomonas naasensis
# s__
# s__Mesorhizobium sp003952505
# s__Streptomyces mashuensis
# s__Nocardioides sp017310035
# s__Kineococcus aurantiacus
# s__Novosphingobium profundi
# s__Actinoplanes sp016464385
# s__Acinetobacter rongchengensis
# s__Sphingomonas kyeonggiensis
# s__Muricauda lutimaris
# s__Arthrobacter_I sp003352915
# s__Bartonella callosciuri
# s__Chitinophaga fulva
# s__Croceicoccus sediminis
# s__Desulfobacillus sp905339315
# s__Thermococcus sp012027355
# s__Prevotella sp902799765
# s__Leifsonia sp017565305
# s__Salinarimonas ramus
# s__Limimorpha sp902770835
# s__Flavobacterium sp003668995
# s__Jiangella endophytica
# s__
# s__Paramesorhizobium salinisoli
# s__Pseudoxanthomonas_A mexicana
# s__Glycomyces sp016918015
# s__Brevundimonas sp017795885
# s__Flavobacterium microcysteis
# s__Kibdelosporangium persicum
# s__Exiguobacterium sp018617855
# s__Paracoccus aestuarii
# s__Neobacillus sp018613415
# s__COE1 sp009774345
# s__Novosphingobium ginsenosidimutans
# s__Sulfuritortus calidifontis
# s__Acetatifactor sp900772845
# s__Thiothrix sp016772315
# ---------------    profile_results/species90_4.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.537037037037037 0.8935011503312377 0.196800844888144 0.58 0.5 58 29 29
# 43 profile_results/species90_4.metaphlan.gtdb
# ---------------    profile_results/species90_4.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.36220472440944884 1.600483966901797 1.4629312646669461 0.23469387755102042 0.7931034482758621 58 46 12
# 5 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8723404255319149 0.7873633180519862 0.09649969796855142 0.82 0.9318181818181819 44 41 3
# 44 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3416666666666667 1.5652384614247175 1.5102838514414607 0.20918367346938777 0.9318181818181819 44 41 3
# profile_results/species90_5.kmcp.profile
# ---------------    profile_results/species90_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5737704918032787 0.8384005438875145 0.4119102562362352 0.7 0.48611111111111116 72 35 37
# 44 profile_results/species90_5.kmcp.profile
# ---------------    profile_results/species90_5.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3208955223880597 1.479735593553075 1.344271341660916 0.2193877551020408 0.5972222222222222 72 43 29
# profile_results/species90_5.ganon.tre
# ---------------    profile_results/species90_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.4696969696969697 0.8057228542531996 0.5353955731056682 0.62 0.3780487804878049 82 31 51
# 44 profile_results/species90_5.ganon.tre
# ---------------    profile_results/species90_5.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.2661870503597122 1.4484594532875377 1.2528890036615268 0.18877551020408162 0.4512195121951219 82 37 45
# profile_results/species90_5_bracken_species.kreport
# ---------------    profile_results/species90_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.13953488372093015 0.839634323433998 1.378688228913803 0.78 0.0766208251473477 509 39 470
# 44 profile_results/species90_5_bracken_species.kreport
# ---------------    profile_results/species90_5_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.37163120567375885 0.9276155965093433 0.29943712126930866 0.6683673469387755 0.2573673870333988 509 131 378
# profile_results/species90_5.metaphlan.gtdb
# s__Dysosmobacter sp910585385
# s__Thermophilibacter sp014982725
# s__Microbacterium hydrothermale
# s__Methylobacterium sp014191355
# s__Anaerostipes rhamnosivorans
# s__Cloacibacterium rupense
# s__Athalassotoga saccharophila
# s__Marinomonas aquiplantarum
# s__
# s__Frigoribacterium sp017833035
# s__Lentzea indica
# s__Frigoribacterium faeni
# s__Pedobacter sp004331735
# s__Pseudomonas_E sp012935695
# s__Massilia aromaticivorans
# s__Enterococcus_B sp017316305
# s__Pseudoduganella lurida
# s__Tardiphaga sp018279705
# s__Sodaliphilus sp902762385
# s__Levilactobacillus fujinensis
# s__Pseudomonas_E sp013179515
# s__CAG-170 sp900553545
# s__Flavobacterium sp004349315
# s__Microbacterium oleivorans_C
# s__Pseudomonas_D xiamenensis
# s__TMED112 sp902619265
# s__Streptomyces sp011421595
# s__Halostella sp003675875
# s__Sphingomonas sp004101245
# s__Actinoplanes sp016464385
# s__Rossellomorea sp008364765
# s__Buchnera aphidicola_AI
# s__Halomonas sp003339685
# s__Roseovarius dicentrarchi
# s__
# s__Cryobacterium sp004403945
# s__Enorma burkinafasonensis
# s__Streptomyces syringium
# s__Brevundimonas sp017744255
# s__Deinococcus aerolatus
# s__Nocardioides eburneiflavus
# s__Protaetiibacter sp014483895
# s__UBA1711 sp902762805
# s__Fimisoma sp905214195
# s__Bifidobacterium vaginale_H
# s__Geothrix sp903839205
# s__Blautia_A luti
# s__
# s__Kitasatospora sp002953255
# s__Corallococcus sicarius
# s__Coprenecus sp900550465
# s__Methylobacterium oxalidis
# s__UBA11549 sp900768185
# s__Aromatoleum toluvorans
# s__Blastococcus sp016612865
# s__Mesobacillus boroniphilus_A
# s__Mucispirillum sp910586745
# s__Actinosynnema algeriensis
# s__Halomonas ventosae_C
# s__Blastococcus saxobsidens_B
# s__Actinoplanes ianthinogenes
# s__Streptomyces phyllanthi
# s__Aeromicrobium piscarium
# s__Sphingopyxis sp005502465
# ---------------    profile_results/species90_5.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6666666666666666 0.8458671907899371 0.27158065420431027 0.74 0.6065573770491803 61 37 24
# 44 profile_results/species90_5.metaphlan.gtdb
# ---------------    profile_results/species90_5.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.40466926070038917 1.5791468984521224 1.5134072315400744 0.2653061224489796 0.8524590163934427 61 52 9
# 6 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8409090909090908 0.76831940409471 0.10010024092368834 0.7551020408163265 0.9487179487179487 39 37 2
# 40 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.31223628691983124 1.5233639947737783 1.4555650162365632 0.18686868686868688 0.9487179487179487 39 37 2
# profile_results/species90_6.kmcp.profile
# ---------------    profile_results/species90_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6115702479338844 0.8473443518798554 0.301857047266321 0.7551020408163265 0.5138888888888888 72 37 35
# 40 profile_results/species90_6.kmcp.profile
# ---------------    profile_results/species90_6.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.34814814814814815 1.52041093792973 1.2817453039502154 0.23737373737373738 0.6527777777777778 72 47 25
# profile_results/species90_6.ganon.tre
# ---------------    profile_results/species90_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.4770642201834863 0.7863220069750286 0.6032025073968931 0.5306122448979592 0.43333333333333335 60 26 34
# 40 profile_results/species90_6.ganon.tre
# ---------------    profile_results/species90_6.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.24031007751937986 1.407817059871324 1.126005366937072 0.15656565656565657 0.5166666666666666 60 31 29
# profile_results/species90_6_bracken_species.kreport
# ---------------    profile_results/species90_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.09728183118741053 0.835597019574743 1.396427988052914 0.6938775510204082 0.05230769230769228 650 34 616
# 40 profile_results/species90_6_bracken_species.kreport
# ---------------    profile_results/species90_6_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.2806603773584905 1.181742792436717 0.21809942554325729 0.601010101010101 0.18307692307692303 650 119 531
# profile_results/species90_6.metaphlan.gtdb
# s__Pseudomonas_E sp016650815
# s__MAG-121220-bin8 sp018662905
# s__Halorubrum sp003990725
# s__
# s__Prevotella sp900553155
# s__Phocaeicola sp900551645
# s__Sphingomonas kyeonggiensis_A
# s__Ensifer sesbaniae
# s__Parolsenella sp900543875
# s__Thermococcus_B sp012027325
# s__Intestinibacter sp900540355
# s__Novosphingobium sp004342985
# s__
# s__Sphingomonas_B horti
# s__Enterococcus sp017377505
# s__Chryseobacterium sp003669035
# s__Sphingomonas sp012650175
# s__Mucilaginibacter sp013149275
# s__Duganella aceris
# s__Psychrobacter immobilis_E
# s__Methanothrix sp017994055
# s__Flavobacterium palustre
# s__Bhargavaea sp009761675
# s__Buchnera aphidicola_R
# s__Vulcanococcus sp018502385
# s__Leptospira stimsonii_A
# s__Methylobacterium sp017833295
# s__Wolbachia sp003344345
# s__Agromyces aurantiacus
# s__Novosphingobium profundi
# s__Rhodoferax bucti
# s__Flavobacterium cutihirudinis
# s__
# s__Buttiauxella colo
# s__Bin65 sp011523655
# s__Limnobacter alexandrii
# s__Acinetobacter piscicola_A
# s__Tateyamaria sp007995245
# s__Geodermatophilus sp004571065
# s__Streptomyces spinoverrucosus
# s__Lacticaseibacillus chiayiensis
# s__Nodosilinea sp014695395
# s__Streptomyces showdoensis
# s__Bradyrhizobium campsiandrae
# s__UBA3789 sp902776735
# s__Phenylobacterium haematophilum
# s__Azospirillum soli
# s__Luteimonas sp902506295
# s__Leifsonia sp013359685
# s__Tersicoccus solisilvae
# s__
# s__Paenibacillus_A lentus
# s__LEGE-XX443 sp015206815
# s__Marinomonas balearica
# s__CAG-115 sp900768125
# s__F0422 sp003999875
# s__Roseivivax sp009363255
# s__BD2-11 sp009840525
# s__
# s__Mycobacterium gordonae_D
# s__Herminiimonas sp003852535
# ---------------    profile_results/species90_6.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6285714285714286 0.9384873337306052 0.6334800957304346 0.673469387755102 0.5892857142857143 56 33 23
# 40 profile_results/species90_6.metaphlan.gtdb
# ---------------    profile_results/species90_6.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.39370078740157477 1.6788468415027917 1.5818742142955515 0.25252525252525254 0.8928571428571429 56 50 6
# 7 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8478260869565218 0.6932270010321172 0.11041613804175449 0.78 0.9285714285714286 42 39 3
# 42 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3277310924369748 1.3716619490790458 1.11242989028114 0.1989795918367347 0.9285714285714286 42 39 3
# profile_results/species90_7.kmcp.profile
# ---------------    profile_results/species90_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5826771653543308 1.0626658430731442 1.129697191004873 0.74 0.48051948051948057 77 37 40
# 42 profile_results/species90_7.kmcp.profile
# ---------------    profile_results/species90_7.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.38095238095238093 1.5690449706819345 1.3434991700335155 0.2653061224489796 0.6753246753246753 77 52 25
# profile_results/species90_7.ganon.tre
# ---------------    profile_results/species90_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.39370078740157477 0.6987092365949958 0.7200302492317608 0.5 0.3246753246753247 77 25 52
# 42 profile_results/species90_7.ganon.tre
# ---------------    profile_results/species90_7.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.2783882783882784 1.2295886182972926 0.9647676154394247 0.19387755102040816 0.49350649350649356 77 38 39
# profile_results/species90_7_bracken_species.kreport
# ---------------    profile_results/species90_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.1416526138279933 0.8460532485305005 0.9060960103380271 0.84 0.07734806629834257 543 42 501
# 42 profile_results/species90_7_bracken_species.kreport
# ---------------    profile_results/species90_7_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3626522327469554 0.9346806738108879 0.3300094822057206 0.6836734693877551 0.24677716390423576 543 134 409
# profile_results/species90_7.metaphlan.gtdb
# s__Chlamydophila sp018343815
# s__
# s__Oenococcus sp004010835
# s__Thermococcus stetteri
# s__Bradyrhizobium archetypum
# s__Acinetobacter sp012371325
# s__Psychroflexus sp010820555
# s__Dolichospermum sp009712035
# s__
# s__Hymenobacter sp018145755
# s__Saccharofermentans sp902764825
# s__ER4 sp900550165
# s__Halosimplex rubrum
# s__Aeromicrobium endophyticum
# s__ER4 sp900546295
# s__BD2-11 sp009840525
# s__Pseudomonas_E sp009707515
# s__Novosphingobium jiangmenense
# s__SAR86A sp902557965
# s__Choladocola sp910587495
# s__Poseidonibacter sp009208075
# s__Nocardiopsis_C mwathae
# s__Nocardioides kongjuensis
# s__Marortus aliphaticivorans_B
# s__Sphingomonas sp004340945
# s__Chryseobacterium sp003815675
# s__Bradyrhizobium diazoefficiens_H
# s__
# s__Prevotella sp900556795
# s__Actinoplanes sp016464385
# s__Exiguobacterium sp018617855
# s__Methylobacterium sp005502455
# s__Bradyrhizobium diazoefficiens_D
# s__Chryseobacterium sp003669035
# s__Prevotella sp902792635
# s__UBA1436 sp900541355
# s__Bradyrhizobium manausense_D
# s__Vagococcus sp003462485
# s__Chryseobacterium bernardetii
# s__Dyella sp016586165
# s__Nocardioides jejuensis
# s__Pararheinheimera sp003990335
# s__Pseudoalteromonas rhizosphaerae
# s__Pelagibacter sp902597335
# s__Saccharopolyspora rhizosphaerae
# s__Jiella pacifica
# s__Ochrobactrum_A sp014397025
# s__Massilia mucilaginosa
# s__Lawsonibacter sp910588635
# s__Paraburkholderia sp017104715
# s__Modestobacter roseus
# s__Limnobacter alexandrii
# s__Paenarthrobacter nicotinovorans_B
# s__Aliiroseovarius marinus
# s__Marinisoma sp902575395
# s__Herminiimonas sp003852535
# s__Nocardioides phosphati
# s__Limivivens sp900543575
# s__Paenibacillus_A timonensis
# s__TCS55 sp018674655
# s__Nitrosocosmicus arcticus
# s__Flavobacterium collinsii
# s__Sphingomonas sp012650175
# s__Nostoc foliaceum_A
# s__Mesorhizobium sp004791585
# s__UBA9926 sp018645765
# s__Prevotella sp900546535
# s__Paenibacillus albilobatus
# s__Anaerobacillus_A sp017303315
# ---------------    profile_results/species90_7.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5436893203883495 0.7320839194954016 0.14947220719603266 0.56 0.5283018867924528 53 28 25
# 42 profile_results/species90_7.metaphlan.gtdb
# ---------------    profile_results/species90_7.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3614457831325301 1.372763602352515 1.0900679491890515 0.22959183673469388 0.8490566037735849 53 45 8
# 8 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.691358024691358 0.6787397281589217 0.17495370114028047 0.56 0.9032258064516129 31 28 3
# 40 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.2456140350877193 1.3361701036039069 1.2969895937344387 0.14213197969543148 0.9032258064516129 31 28 3
# profile_results/species90_8.kmcp.profile
# ---------------    profile_results/species90_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5252525252525253 0.6796989752187673 0.28354423930106326 0.52 0.5306122448979591 49 26 23
# 40 profile_results/species90_8.kmcp.profile
# ---------------    profile_results/species90_8.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.2926829268292683 1.2791318063234136 1.2475326774066327 0.18274111675126903 0.7346938775510203 49 36 13
# profile_results/species90_8.ganon.tre
# ---------------    profile_results/species90_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.46341463414634143 0.681986856498095 0.634414455393485 0.38 0.59375 32 19 13
# 40 profile_results/species90_8.ganon.tre
# ---------------    profile_results/species90_8.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.20087336244541487 1.267657077902959 1.214315687525488 0.116751269035533 0.71875 32 23 9
# profile_results/species90_8_bracken_species.kreport
# ---------------    profile_results/species90_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.13733905579399133 0.6764698926387123 1.1205582959084732 0.64 0.07692307692307687 416 32 384
# 40 profile_results/species90_8_bracken_species.kreport
# ---------------    profile_results/species90_8_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.33278955954323003 0.6793160148538303 0.2578248124243504 0.5177664974619289 0.2451923076923077 416 102 314
# profile_results/species90_8.metaphlan.gtdb
# s__Chryseobacterium sp016595215
# s__Desulfovibrio legallii
# s__
# s__Agromyces salentinus
# s__Fibrobacter succinogenes_C
# s__Kushneria pakistanensis
# s__Chryseolinea soli
# s__Ammonifex thiophilus
# s__Blattabacterium cuenoti_Q
# s__Mesorhizobium sp004136315
# s__
# s__Rhodanobacter sp014842975
# s__Pseudomonas_E sp014268505
# s__Epilithonimonas arachidiradicis
# s__Mesomycoplasma sp012516495
# s__TMED112 sp902619265
# s__
# s__Aliarcobacter suis
# s__Wolbachia sp012277315
# s__Chimaeribacter sp005491205
# s__CAG-302 sp900548425
# s__Marinobacter sp008107725
# s__TMED96 sp902593075
# s__Dyella sp016428905
# s__Flavobacterium sp004362015
# s__CAG-127 sp900767585
# s__Brevundimonas nasdae
# s__Bradyrhizobium tropiciagri_B
# s__Trichormus subtropica
# s__Mesobacillus sp014856545
# s__Lacticaseibacillus chiayiensis
# s__TMED96 sp902598305
# s__Deinococcus humi
# s__
# s__Sphingomonas sp902506455
# s__Rhizobium sp014195095
# s__
# s__Mesorhizobium sp016756535
# s__Kibdelosporangium persicum
# s__Streptomyces actuosus_A
# s__
# s__Streptomyces paludis
# s__
# s__Leifsonia sp017565305
# s__Leucobacter solipictus
# s__Limimaricola variabilis
# s__Rhodanobacter sp009766065
# s__Buttiauxella sp006376615
# s__Paramesorhizobium sp014191375
# s__Enterousia sp900549365
# s__Flavobacterium sp009707955
# s__CACIIZ01 sp902611605
# s__Pseudomonas_E sp014174475
# s__Halomonas sp014931605
# s__Streptomyces sp015999245
# s__Winogradskyella wandonensis
# s__Acinetobacter sp900625095
# ---------------    profile_results/species90_8.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6000000000000001 0.9136068339721053 0.5581815073731546 0.54 0.675 40 27 13
# 40 profile_results/species90_8.metaphlan.gtdb
# ---------------    profile_results/species90_8.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0
metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5438596491228069 0.7114645570245813 0.29189552863395013 0.62 0.484375 64 31 33
# 43 profile_results/species90_9.metaphlan.gtdb
# ---------------    profile_results/species90_9.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.40944881889763773 1.2333803403896757 1.1835223186592667 0.2736842105263158 0.8125 64 52 12
# 10 90
# sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.7954545454545455 0.6852318088393848 0.07765471261140364 0.7 0.9210526315789473 38 35 3
# 44 sylph
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.30434782608695654 1.3606880327582989 1.3314203953197576 0.18229166666666666 0.9210526315789473 38 35 3
# profile_results/species90_10.kmcp.profile
# ---------------    profile_results/species90_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6551724137931033 0.7472381737707251 0.3660844384991575 0.76 0.5757575757575757 66 38 28
# 44 profile_results/species90_10.kmcp.profile
# ---------------    profile_results/species90_10.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.37209302325581395 1.3653243438174978 1.3067342805675646 0.25 0.7272727272727273 66 48 18
# profile_results/species90_10.ganon.tre
# ---------------    profile_results/species90_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5274725274725275 0.7087941064654083 0.5540430103905754 0.48 0.5853658536585367 41 24 17
# 44 profile_results/species90_10.ganon.tre
# ---------------    profile_results/species90_10.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.24892703862660942 1.3297775477165457 1.2049548188188308 0.15104166666666666 0.7073170731707317 41 29 12
# profile_results/species90_10_bracken_species.kreport
# ---------------    profile_results/species90_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.14525139664804473 0.7174108029292344 1.1743885049744 0.78 0.08008213552361398 487 39 448
# 44 profile_results/species90_10_bracken_species.kreport
# ---------------    profile_results/species90_10_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3917525773195877 0.7177644040481496 0.34283279728073346 0.6927083333333334 0.2731006160164271 487 133 354
# profile_results/species90_10.metaphlan.gtdb
# s__Roseomonas nepalensis
# s__Ruminococcus_E sp902766885
# s__Maricaulis sp005871165
# s__Anaerobacillus_A hwajinpoensis_A
# s__Nodosilinea sp014695775
# s__Sphingobium sp013375555
# s__Fusobacterium_A sp900549465
# s__Methanogenium sp009914725
# s__Microcoleus sp015207455
# s__Rhodomicrobium sp018619475
# s__Parolsenella catena
# s__Chimaeribacter sp005491205
# s__Porcincola sp902779575
# s__Pseudomonas_E sp004364435
# s__Heliomicrobium undosum
# s__Lacticaseibacillus hegangensis
# s__Actinobacillus_B aerogenes
# s__Pannonibacter sp009915765
# s__Nitrosopumilus sp006740685
# s__Halorhodospira halophila_A
# s__Allochromatium palmeri
# s__Oerskovia sp015142735
# s__Streptomyces naganishii
# s__Nocardioides eburneiflavus
# s__Leptospira_A congkakensis
# s__Propionibacterium australiense
# s__Kribbella italica
# s__Vulcanococcus sp018502385
# s__Pseudomonas_E sp013386585
# s__Arsenophonus sp900343015
# s__Kitasatospora atroaurantiaca
# s__Thermococcus sp012027355
# s__Streptomyces sp014596445
# s__Mesorhizobium sp003952505
# s__Pseudomonas_E sp013179515
# s__Ruegeria atlantica_F
# s__Rubrimentiphilum sp013036105
# s__Paraburkholderia fungorum_B
# s__Giesbergeria sp017985015
# s__Pseudomonas_E daroniae
# s__Vulcanococcus sp014217875
# s__Microbacterium hydrocarbonoxydans_B
# s__Nocardioides glacieisoli
# s__Halobacillus litoralis
# s__Nocardiopsis sp018207095
# s__Streptomyces globosus
# s__Streptomyces ruber
# s__Azohydromonas caseinilytica
# s__Blastococcus sp005222955
# s__Protaetiibacter intestinalis
# s__Spirillospora sp004349245
# s__Bradyrhizobium jicamae_A
# s__Sulfuritortus calidifontis
# s__
# s__Pelagibacter sp902561765
# s__Martelella sp013459645
# s__Brasilonema sp017982655
# s__Chitinilyticum litopenaei_A
# s__Fusobacterium_A sp900555485
# s__Undibacterium sp009937955
# s__Pelagibacter sp902597335
# s__Flavobacterium psychroterrae
# s__Pseudomonas_E sp016518545
# s__Microbacterium sp004794465
# s__Oceanithermus desulfurans
# ---------------    profile_results/species90_10.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.6185567010309279 0.7946987720320323 0.3095699125596746 0.6 0.6382978723404256 47 30 17
# 44 profile_results/species90_10.metaphlan.gtdb
# ---------------    profile_results/species90_10.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.3598326359832636 1.3872975881266687 1.3297374514429676 0.22395833333333334 0.9148936170212766 47 43 4

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cm = 1/2.54  # centimeters in inches\n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})
genus_results = True
fig, axes = plt.subplots(1, 3, figsize=(8*cm, 4.5*cm), sharey=False)
#plt.subplots_adjust(hspace=0.0)
metaphlan = False
if not genus_results:
    #metrics = ['f1', 'precision', 'sensitivity', 'l1_constrain']
    metrics = ['precision', 'sensitivity', 'l1_constrain']
    # Define the test setups and metrics
    test_setups = ["95-97.5% ANI (50 genomes) + 85-90% ANI (150 genome holdout) "] 
    #               "95-97.5% ANI (200 genomes)",
    #               "97.5-99.9% ANI (200 genomes)"]
else:
    #metrics = ['f1 genus', 'precision genus', 'sensitivity genus', 'l1genus']
    metrics = ['precision genus', 'sensitivity genus', 'l1genus']
    # Define the test setups and metrics
    #test_setups = ["Genus-level results: 95-97.5% ANI (50 genomes) +\n85-90% ANI (150 genomes)"] 
    test_setups = [""] 
    #               "95-97.5% ANI (200 genomes)",
    #               "97.5-99.9% ANI (200 genomes)"]
y_positions = [1, 0.65, 0.30]

# Loop through the test setups and metrics to fill the grid
for i, setup in enumerate(test_setups):
    if metaphlan:
        methods = ['sylph', 'KMCP', 'ganon', 'Bracken', 'MetaPhlAn4*']
    else:
        methods = ['sylph', 'KMCP', 'ganon', 'Bracken']
    if metaphlan:
        stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats, metaphlan_stats]
    else:
        stats_l = [sylph_stats, kmcp_stats, ganon_stats, kraken_stats]
    for j, metric in enumerate(metrics):
        if genus_results:
            stats_l = [[sylph_stats_all,[],[]],
                       [kmcp_stats_all,[],[]], 
                       [ganon_stats_all,[],[]],
                       [kraken_stats_all,[],[]]]
        if metaphlan:
            stats_l.append([metaphlan_stats_all,[],[]])
        ax = axes[j]
        
        # Extract the data for this subplot
        data_to_plot = []
        for k, method_stats in enumerate(stats_l):
            #print(method_stats[i])
            method_data = [x[metric] for x in method_stats[i]]
            data_to_plot.append(method_data)
        
        # Create the boxplot with smaller width
        ci = True if genus_results else True
        if j < 2:
            sns.barplot(data=data_to_plot, ax=ax, palette="muted",ci = ci)
            ax.set_ylim([0,1])
        else:
            sns.boxplot(data=data_to_plot, ax=ax, palette="muted")
            ax.set_ylim([0,1.7])
            
        # Add labels
        ax.set_xticklabels(methods)
        ax.set_ylabel(metric.capitalize())
        ax.set_ylabel("")
        if genus_results:
            ax.set_title(metric.capitalize(),fontsize=7)
        else:
            ax.set_title(metric.capitalize() + ' species', fontsize=7)
        #if j == 4:
        #    ax.set_title('Norm. L1 (genus)', fontsize=7)
        if j == 2:
            if genus_results:
                ax.set_title('Norm. L1 (genus)', fontsize=7)
            else:
                ax.set_title('Norm. L1 (species)', fontsize=7)

        #if j == 2:
           # ax.set_title(test_setups[i], fontsize=7.0)
        
        # Remove the top and right borders
        sns.despine(ax=ax)
        ax.tick_params(axis='x', rotation=75)
        #if i != 2:
        #    ax.set_xticks([])
    for (k,ax) in enumerate(axes[:2]):
        for p in ax.patches:
            add_h = 0.03
            if genus_results:
                add_h = 0.00
            ax.annotate(f'{round(p.get_height(),2)}', (p.get_x() + p.get_width() / 2., p.get_height() + add_h,),
                    ha='center', va='bottom',fontsize=6)
    # Add one title per row in the middle
    #fig.text(0.5, y_positions[i], setup, ha="center", va="center", fontsize=9)
fig.text(0.5, 1, test_setups[0], ha='center', va='bottom')
# Show the grid of plots
plt.tight_layout()
save = 'figures/f2-ani_r89_benchmark.svg'
if genus_results:
    save = 'figures/genus-f2-ani_r89_benchmark.svg'
if 'MetaPhlAn4*' in methods:
    save += '-metaphlan.svg'
plt.savefig(save)
plt.show()

# %%
# Roc analysis
fig, axes = plt.subplots(1, figsize=(7* cm, 7 * cm), sharey=True)

for i in [0]:
    d = [[sylph_rocs[i]], 
        [kmcp_rocs[i]],
        [ganon_rocs[i]],
        [kraken_rocs[i]],]
     #   [metaphlan_rocs[i]]]
    data = []
    for i in range(len(d)):
        concat = []
        for j in range(10):
            concat += d[i][0][j]
        data.append(concat)
    ordered_labels = ['sylph',  'KMCP', 'Ganon', 'Bracken', 'MetaPhlAn4*']

    c = [cmap[0], cmap[1], cmap[2], cmap[3]]
    for j in range(len(c)):
        points = 20
        xs = np.linspace(0,1,points+1)
        ys = [[data[j][i][1] for i in range(len(data[j])) if data[j][i][0] < xs[k+1] and data[j][i][0] >= xs[k]] 
              for k in range(points)]
        xs = [xs[i] for i in range(points) if ys[i] != []]
        ys = [ys[i] for i in range(points) if ys[i] != []]
        di = []
        for l in range(len(ys)):
            print(l, xs[l])
            di += [(xs[l],ys[l][k]) for k in range(len(ys[l]))]
        df = pd.DataFrame(di)
        ax = sns.lineplot(data=df, x = 0, y = 1,ax=axes, color=c[j], label = ordered_labels[j])
    #ax.set_xticklabels(ordered_labels)
    ax.set_ylabel('Precision')
    ax.set_xlabel("Recall")
    plt.xlim([0,1])
    plt.ylim([0,1])
    #ax.set_title(titles[i])

    #ax.set_title(test_setups[i], fontsize=7)
    
    # Remove the top and right borders
    sns.despine(ax=ax)
    #ax.tick_params(axis='x', rotation=75)
plt.legend(frameon=False)
if roc_genus:
    plt.title('Precision-recall curve\n50 species/150 genus community (genus)')
    plt.savefig('supp_figs/fig1-curve-genus.svg')
else:
    plt.title('Precision-recall curve\n50 species/150 genus community (species)')
    plt.savefig('supp_figs/fig1-curve-species.svg')
plt.show()
# Out:
# 0 0.0
# 1 0.05
# 2 0.1
# 3 0.15000000000000002
# 4 0.2
# 5 0.25
# 6 0.30000000000000004
# 7 0.35000000000000003
# 8 0.4
# 9 0.45
# 10 0.5
# 11 0.55
# 12 0.6000000000000001
# 13 0.65
# 14 0.7000000000000001
# 15 0.75
# 16 0.8
# 0 0.0
# 1 0.05
# 2 0.1
# 3 0.15000000000000002
# 4 0.2
# 5 0.25
# 6 0.30000000000000004
# 7 0.35000000000000003
# 8 0.4
# 9 0.45
# 10 0.5
# 11 0.55
# 12 0.6000000000000001
# 13 0.65
# 14 0.7000000000000001
# 15 0.75
# 0 0.0
# 1 0.05
# 2 0.1
# 3 0.15000000000000002
# 4 0.2
# 5 0.25
# 6 0.30000000000000004
# 7 0.35000000000000003
# 8 0.4
# 9 0.45
# 10 0.5
# 11 0.55
# 12 0.6000000000000001
# 0 0.0
# 1 0.05
# 2 0.1
# 3 0.15000000000000002
# 4 0.2
# 5 0.25
# 6 0.30000000000000004
# 7 0.35000000000000003
# 8 0.4
# 9 0.45
# 10 0.5
# 11 0.55
# 12 0.6000000000000001
# 13 0.65
# 14 0.7000000000000001
# 15 0.75
# 16 0.8
# 17 0.8500000000000001

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize empty lists to store data
time_data = []
cpu_time_data = []
memory_data = []

plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})

# Function to read and parse benchmark data
def read_benchmark_data(filename, method, num_samples=1):
    with open(filename, 'r') as f:
        lines = f.readlines()
        headers = lines[0].strip().split('\t')
        values = lines[1].strip().split('\t')

        time_index = headers.index('s')
        cpu_time_index = headers.index('cpu_time')
        memory_index = headers.index('max_rss')

        time_data.append({'method': method, 'time': float(values[time_index])/num_samples})
        cpu_time_data.append({'method': method, 'cpu_time': float(values[cpu_time_index])/num_samples})
        memory_data.append({'method': method, 'memory': float(values[memory_index])/1000})

# Loop through each experiment and collect data
for exp in ['species90', 'species96', 'species98']:
    for method in [ 'kmcp', 'ganon', 'kraken', 'metaphlan', 'motus']:
        for iter_file in glob.glob(f'fig2_benchmarks/{exp}/{exp}_*.{method}.benchmark'):
            read_benchmark_data(iter_file, method)

# Read sylph data (let's assume you have 30 samples for sylph)
read_benchmark_data('fig2_benchmarks/sylph.benchmark', 'sylph', num_samples=30)

# Convert lists of dictionaries to DataFrames
time_df = pd.DataFrame(time_data)
cpu_time_df = pd.DataFrame(cpu_time_data)
memory_df = pd.DataFrame(memory_data)

method_to_label = {
    'ganon': 'ganon',
    'kmcp': 'KMCP',
    'kraken': 'Bracken',
    'sylph': 'sylph',
    'metaphlan': 'MetaPhlAn4*',
    'motus': 'mOTUs3*'
    
}


# Replace the method names in the DataFrames
time_df['method'] = time_df['method'].map(method_to_label)
cpu_time_df['method'] = cpu_time_df['method'].map(method_to_label)
memory_df['method'] = memory_df['method'].map(method_to_label)
# Create subplots

fig, axes = plt.subplots(1, 3, figsize=(16*cm, 5*cm))
p = sns.color_palette("muted")
palette = [p[0],p[1],p[2],p[3],p[4],p[6]]
ordered_labels = ['sylph',  'KMCP', 'ganon','Bracken', 'MetaPhlAn4*', 'mOTUs3*']
# Plot the wall time, CPU time and memory
ax1 = sns.barplot(y='time', x='method', log=True, data=time_df, estimator=lambda x: sum(x)/len(x), ax=axes[0], ci=False, palette=palette, order=ordered_labels)
ax2 = sns.barplot(y='cpu_time', x='method', log=True,  data=cpu_time_df, estimator=lambda x: sum(x)/len(x), ax=axes[1], ci=False, palette=palette, order=ordered_labels)
ax3 = sns.barplot(x='method', y='memory', data=memory_df, estimator=max, ax=axes[2], palette=palette, order=ordered_labels, ci=False)

ax1.set(xlabel='', ylabel='Average wall time (s)')
ax2.set(xlabel='', ylabel='Average CPU time (s)')
ax3.set(xlabel='', ylabel='Max memory (GB)')

# Add titles and remove top and right borders
titles = ['Average Wall Time (s)', 'Average CPU Time (s)', 'Max Memory (RSS)']
for ax, title in zip(axes, titles):
    #ax.set_title(title)
    sns.despine(ax=ax)

# Annotate bars with integers
for (k,ax) in enumerate(axes):
    for p in ax.patches:
        v = round(p.get_height())
        if p.get_height() < 10:
            v = round(p.get_height(),1)
        if k == 2:
            ax.annotate(f'{v}', (p.get_x() + p.get_width() / 2., p.get_height() + 2 ),
                    ha='center', va='bottom')
        else:
            ax.annotate(f'{v}', (p.get_x() + p.get_width() / 2., p.get_height() * 1.1 ),
                    ha='center', va='bottom')
    ax.tick_params(axis='x', rotation=75)

#plt.suptitle('Performance Metrics Across All Methods, Samples, and Experiments')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.savefig('figures/f2-ani_profile_benchmark_times.svg')
plt.show()

# %%
def truth_strat(file_path, spec_to_metadata, ref_to_spec, spec90 = False):
    taxonomic_data = dict()
    results = []
    with open(file_path, 'r') as f:
        csv_reader = csv.reader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            gn = spl[-1].strip().split('/')[-1].split('_genomic')[0][3:]
            
            spec = ref_to_spec[gn]
            seq_abund = float(spl[1])
            size = float(spec_to_metadata[spec[1]]['genome_size'])
            data = tax_result(spec[1], spec[0], size, seq_abund)
            if spec90:
                if len(results) >= 50:
                    break
            results.append(data)
    total_cov = 0
    total_seq = 0
    for r in results:
        total_cov += r.abund * r.seq_abund
        total_seq += r.seq_abund
    for r in results:
        r.abund = r.abund * r.seq_abund / total_cov
        #r.seq_abund = r.seq_abund / total_seq
        if r.species in taxonomic_data:
            #print(r.species)
            taxonomic_data[r.species].seq_abund += r.seq_abund 
            taxonomic_data[r.species].abund += r.abund 
        else:
            taxonomic_data[r.species] = r
    return taxonomic_data

def truth_detect(truth, stats):
    res = []
    for species in stats.keys():
        if species not in truth:
            res.append([stats[species].seq_abund, 0])
        else:
         #   print('succ')
            res.append([stats[species].seq_abund, 1])
            
    return res


def truth_sense(truth, stats):
    res = []
    for species in truth.keys():
        if species not in stats:
            res.append([truth[species].seq_abund, 0])
        else:
         #   print('succ')
            res.append([truth[species].seq_abund, 1])
            
    return res
    
sylph_results,sylph_gen_results = read_sylph('strat_profile_results/sylph_output.tsv', ref_to_spec)
anis = [95,96,97,98,99]
strat_stats = []
its = range(1,10)

for (i,diff) in enumerate(anis):
    for it in its:
        files = [' ', f'strat_profile_results/species{diff}_{it}.tsv',
               'sylph',
             f'strat_profile_results/species{diff}_{it}.kmcp.profile',
             f'strat_profile_results/species{diff}_{it}.ganon.tre',
            f'strat_profile_results/species{diff}_{it}_bracken_species.kreport',
            f'strat_profile_results/species{diff}_{it}.metaphlan.gtdb',
              ]

        truth_data = truth_strat(files[1], spec_to_metadata,ref_to_spec)
        results = files[2:]
        
        rg = "ref_genomes/"
        out = ""
        print(it,diff)
        for result in results:
            if 'ganon' in result:
                results,gen_results = read_ganon_file(result, species_name_to_spec, spec_to_metadata)
                out = f"{rg}{diff}_{it}.ganon.sh"
            elif 'sylph' in result:
                gen_results = sylph_gen_results[(diff,it)]
                results = sylph_results[(diff,it)]
                out = f"{rg}{diff}_{it}.sylph.sh"
            elif 'ken' in result:
                results,gen_results = read_kraken_file(result, species_name_to_spec, spec_to_metadata, kraken_cutoff)
                out = f"{rg}{diff}_{it}.kraken.sh"
                #compare_to_truth(results, truth_data)
                #results = read_kraken_file(result, species_name_to_spec, spec_to_metadata, 0.01 / 100)
            elif 'kmcp' in result:
                out = f"{rg}{diff}_{it}.kmcp.sh"
                results,gen_results = read_kmcp_file(result, species_name_to_spec, spec_to_metadata)
            elif 'metaphlan' in result:
                if diff == 90:
                    continue
                out = f"{rg}{diff}_{it}.metaphlan.sh"
                results,gen_results = read_metaphlan(result, spec_to_metadata, r207_to_r89)

            debug = False
            #print(results)
            stats = compare_to_truth(results, gen_results, truth_data, result, debug)
            detect = truth_detect(truth_data, results)
            sense = truth_sense(truth_data, results)
            meth = ""
            ANI = diff
            if 'sylph' in result:
                method= "sylph"
            elif 'kmcp' in result:
                method = "KMCP"
            elif 'ganon' in result:
                method = "ganon"
            elif 'ken' in result:
                method ='Bracken\n0.01% cutoff'
            elif 'metaphlan' in result:
                method = "MetaPhlAn4*"
            else:
                continue
            #print(stats)
            strat_stats.append({"method":method, "ani": f"[{ANI},{ANI+1})", "Precision" : stats['precision'], "Sensitivity": stats['sensitivity'], "detect":detect, "sense": sense})
# Out:
# 1 95
# g__Paraburkholderia
# g__Haloarcula
# g__Streptococcus
# g__20-14-0-20-35-9
# g__Streptococcus
# g__Streptomyces
# g__Gillisia
# g__UBA6794
# g__Ruminococcus_E
# g__Streptomyces
# g__Streptococcus
# g__Gilliamella
# g__Bradyrhizobium
# g__Vibrio
# g__Lachnoanaerobaculum
# g__Collinsella
# g__UBA11996
# g__Campylobacter_A
# g__Leptospirillum_A
# g__TMED189
# g__Neorhizobium
# g__UBA5619
# g__UBA1100
# g__Sulfurimonas
# g__Halomonas
# g__Streptococcus
# g__CAG-302
# g__Streptococcus
# g__Acidovorax_D
# g__Bombella
# g__Marinimicrobium
# g__Enterococcus_E
# g__Chryseobacterium
# g__Cloacibacterium
# g__Janthinobacterium
# g__Proteus
# g__Bacteroides
# g__Bradyrhizobium
# g__Roseovarius
# g__Terrisporobacter
# g__Microcoleus
# g__Collinsella
# g__Acinetobacter
# g__Streptococcus
# g__Streptococcus
# g__CAG-451
# g__Bradyrhizobium
# g__Pseudomonas_E
# g__Neisseria
# g__Rhizobacter
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.
metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8723404255319149 0.18699877804114376 0.16443926524292993 0.82 0.9318181818181819 44 41 3

# %%
import pandas as pd
import seaborn as sns
df = pd.DataFrame(strat_stats)
from collections import defaultdict
p = sns.color_palette("muted")
import warnings
warnings.filterwarnings('ignore')
import matplotlib 
#df.apply(lambda x: np.round(np.log(x['detect'][0]) * 2)/2, axis=1)
detects = defaultdict(list)
senses = defaultdict(list)
for method,x in df.groupby(['method','ani']):
#for method,x in df.groupby(['method']):
    #print(method)
    detects[tuple(method)] += list(x['detect'])
    senses[tuple(method)] += list(x['sense'])
    #print(x['detect'])
det_95 = [] 
det_99 = []
det = []
sense = []
ordered_labels = ['sylph',  'KMCP', 'ganon','Bracken\n0.01% cutoff']#, 'MetaPhlAn4*']

for method, d in detects.items():
    for res in d:
        for thing in res:
            det.append({"method":method[0], "ab" : round(np.log10(thing[0] * 100) * 2)/2, "det" : thing[1]})
            #print(thing)       
            if '[99' in method[1]:
                det_99.append({"method":method[0], "ab" : round(np.log10(thing[0] * 100) * 2)/2, "det" : thing[1]})
            if '[95' in method[1]:
                det_95.append({"method":method[0], "ab" : round(np.log10(thing[0] * 100) * 2)/2, "det" : thing[1]})

for method, d in senses.items():
    for res in d:
        for thing in res:
            sense.append({"method":method[0], "ab" : round(np.log10(thing[0] * 100) * 2)/2, "det" : thing[1]})
                
       # print(res)
        #res[0] = np.round(np.log(res[0]) * 2) / 2
   # d = np.array(d)

df_det_95 = pd.DataFrame(det_95)
df_det_99 = pd.DataFrame(det_99)
df_det = pd.DataFrame(det)
df_sense = pd.DataFrame(sense)

df_det['ab'] = df_det['ab'].apply(lambda x: 10**x)
df_sense['ab'] = df_sense['ab'].apply(lambda x: 10**x)

print(df_sense.head())
fig, axes = plt.subplots(2, 2, figsize=(8*cm, 9*cm), sharey=False)
g = sns.lineplot(x='ani',y='Precision',data=df,hue='method',ax=axes[0][0], palette = p,hue_order=ordered_labels)
sns.lineplot(x='ani',y='Sensitivity',data=df,hue='method',ax=axes[1][0], palette = p,hue_order=ordered_labels)
sns.lineplot(x ='ab', y = 'det', data = df_det, ax = axes[0][1], hue='method', hue_order=ordered_labels, palette = p)
sns.lineplot(x ='ab', y = 'det', data = df_sense, ax = axes[1][1], hue='method', hue_order=ordered_labels, palette = p)

print(df.groupby(['method','ani'])['Precision'].mean())

#sns.lineplot(x ='ab', y = 'det', data = df_det_99, ax = axes[2], hue='method', hue_order=ordered_labels, ci = False)

for l,axs in enumerate(axes):
    for ax in axs:
        ax.legend([],[], frameon=False)
        if l == 2:
            ax.tick_params(axis='x', rotation=45)
        ax.set_xlabel("ANI")
        sns.despine(ax=ax)
#axes[0][0].set_xlabel("")
axes[0][0].tick_params(axis='x', labelrotation=45)
axes[1][0].tick_params(axis='x', labelrotation=45)

axes[0][1].set_xlabel("Abundance (true)")
#axes[2].set_ylabel("Precision")
axes[0][1].set_xscale('log')
axes[0][1].set_xlim([0.01,10])
#axes[0][1].set_xlabel("")
axes[0][1].set_ylabel("Precision")
axes[1][1].set_xlabel("Abundance (est)")
axes[1][1].set_ylabel("Sensitivity")
axes[1][1].set_xscale('log')
#axes[2].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#axes[3].get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
axes[1][1].set_xlim([0.01,10])

handles, labels = axes[0][0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=4, frameon=False,bbox_to_anchor=(0.5,1.0))
plt.tight_layout()
if 'MetaPhlAn4*' in ordered_labels:
    print('metaphlan')
    plt.savefig("supp_figs/supp-strat_plot_metaphlan.svg")
else:
    plt.savefig("figures/f2-stratified_plots.svg")

#plt.show()
#plt.figure(figsize=(3,3))
#sns.lineplot(x ='ab', y = 'det', data = df_det_95,  hue='method', hue_order=ordered_labels)
#sns.lineplot(x ='ab', y = 'det', data = df_det_99,  hue='method', hue_order=ordered_labels)
# Out:
#                   method         ab  det
# 0  Bracken\n0.01% cutoff   0.100000    1
# 1  Bracken\n0.01% cutoff   1.000000    1
# 2  Bracken\n0.01% cutoff  10.000000    1
# 3  Bracken\n0.01% cutoff   1.000000    1
# 4  Bracken\n0.01% cutoff   0.316228    1
# method                 ani
# Bracken\n0.01% cutoff  [95,96)     0.176424
#                        [96,97)     0.206098
#                        [97,98)     0.282578
#                        [98,99)     0.352381
#                        [99,100)    0.482502
# KMCP                   [95,96)     0.604686
#                        [96,97)     0.623740
#                        [97,98)     0.807563
#                        [98,99)     0.867910
#                        [99,100)    0.932299
# MetaPhlAn4*            [95,96)     0.827735
#                        [96,97)     0.793613
#                        [97,98)     0.904537
#                        [98,99)     0.918692
#                        [99,100)    0.953766
# ganon                  [95,96)     0.388572
#                        [96,97)     0.425505
#                        [97,98)     0.615568
#                        [98,99)     0.672074
#                        [99,100)    0.754384
# sylph                  [95,96)     0.907614
#                        [96,97)     0.938818
#                        [97,98)     0.987703
#                        [98,99)     0.989925
#                        [99,100)    0.986449
# Name: Precision, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
cm = 1/2.54
cm = 1/2.54  # centimeters in inches\n",
    ##Change this to get a bigger figure. \n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})
genus_plot = True
cust_plot = True

#sylph_cami = pd.read_csv("sylph_opal/by_tool/sylph.profile.tsv",sep='\t')
sylph_cami = pd.read_csv("sylph_marmg_v0.5_opal/by_tool/sylph_marmg_v0.5.profile.tsv",sep='\t')

bracken_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.bracken_2.2.profile.tsv",sep='\t')
metaphlan_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.metaphlan2_2.9.22.profile.tsv",sep='\t')
kmcp_cami = pd.read_csv("kmcp_m3_test/by_tool/kmcp-se-r1.c-m3.profile.tsv",sep='\t')
motus_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.motus_2.5.1.profile.tsv",sep='\t')
metaphlan4_cust = pd.read_csv("metaphlan4_motus_opal/by_tool/metaphlan_marine_all.profile.tsv",sep='\t')
motus3_cust = pd.read_csv("metaphlan4_motus_opal/by_tool/motus_ocean_all.profile.tsv",sep='\t')

if cust_plot:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
                    kmcp_cami.assign(method='KMCP'),
                bracken_cami.assign(method='Bracken'), 
               metaphlan_cami.assign(method='MetaPhlAn2'),
               motus_cami.assign(method='mOTUs v2.5'),
                metaphlan4_cust.assign(method='MetaPhlAn4*'),
                 motus3_cust.assign(method='mOTUs v3*'),
                     ])
elif genus_plot:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
                        kmcp_cami.assign(method='KMCP'),
                    bracken_cami.assign(method='Bracken'), 
                   metaphlan_cami.assign(method='MetaPhlAn2'),
                   motus_cami.assign(method='mOTUs v2.5'),])
else:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
                        kmcp_cami.assign(method='KMCP'),
                    bracken_cami.assign(method='Bracken'), 
                   metaphlan_cami.assign(method='MetaPhlAn2'),
                   motus_cami.assign(method='mOTUs v2.5'),])   

pc = sns.color_palette("muted")
df = df_a.loc[df_a['rank'] == 'species']
df["F1 score"] = pd.to_numeric(df["F1 score"])
df["F1 score"] = pd.to_numeric(df["F1 score"])
df["L1 norm error"] = pd.to_numeric(df["L1 norm error"])
df_g = df_a.loc[df_a['rank'] == 'genus']
df_g["L1 norm error"] = pd.to_numeric(df_g["L1 norm error"])
df_g["F1 score"] = pd.to_numeric(df_g["F1 score"])
df_g["Purity"] = pd.to_numeric(df_g["Purity"])

if genus_plot:
    p = [pc[0], pc[1], pc[3], pc[4], pc[9]]
    if cust_plot:
        p.append(pc[5])
        p.append(pc[6])
    fig, axes = plt.subplots(1, 4, figsize=(16*5/5*cm, 5*cm), sharey=False)
    sns.barplot(x = 'method', y = 'F1 score', data = df_g, ax = axes[0], palette = p)
    sns.barplot(x = 'method', y = 'Purity', data = df_g, ax = axes[1], palette = p)
    sns.barplot(x = 'method', y = 'Completeness', data = df_g, ax = axes[2], palette = p)
    sns.boxplot(x = 'method', y = 'L1 norm error', data = df_g, ax = axes[3], palette = p)
    ylabels = ["F1", "Precision", "Sensitivity", "Norm. L1 (genus)"]
else:
    p = [pc[0], pc[1], pc[3], pc[4], pc[9]]
    if cust_plot:
        p.append(pc[5])
        p.append(pc[6])
    if cust_plot:
        num_plots = 4
    else:
        num_plots = 5
    fig, axes = plt.subplots(1, num_plots, figsize=(16*cm, 5*cm), sharey=False)
    sns.barplot(x = 'method', y = 'F1 score', data = df, ax = axes[0], palette = p)
    sns.barplot(x = 'method', y = 'Purity', data = df, ax = axes[1], palette = p)
    sns.barplot(x = 'method', y = 'Completeness', data = df, ax = axes[2], palette = p)
    sns.boxplot(x = 'method', y = 'L1 norm error', data = df, ax = axes[3], palette = p)
    if not cust_plot:
        sns.boxplot(x = 'method', y = 'L1 norm error', data = df_g, ax = axes[4], palette = p)
    ylabels = ["F1", "Precision", "Sensitivity", "Norm. L1 (species)", "Norm. L1 (genus)"]
for i,ax in enumerate(axes):
    if i < 3:
        ax.set_ylim([0,1])
    ax.set_xlabel("")
    sns.despine(ax=ax)
    #ax.set_ylabel(ylabels[i])
    ax.set_ylabel("")
    ax.set_title(ylabels[i], fontsize=7,pad=10)
    ax.tick_params(axis='x', rotation=75)

print(df.groupby('method')['L1 norm error'].median())
print(df_g.groupby('method')['L1 norm error'].median())

#fig, axes = plt.subplots(1, 3, figsize=(18*cm, 5*cm), sharey=False)
#df = df_a.loc[df_a['rank'] == 'genus']
#df["F1 score"] = pd.to_numeric(df["F1 score"])
#df["F1 score"] = pd.to_numeric(df["F1 score"])
#df["L1 norm error"] = pd.to_numeric(df["L1 norm error"])

#sns.barplot(x = 'method', y = 'F1 score', data = df, ax = axes[0], palette = p)

#sns.barplot(x = 'method', y = 'Purity', data = df, ax = axes[1], palette = p)

#sns.boxplot(x = 'method', y = 'L1 norm error', data = df, ax = axes[2], palette = p)
for (k,ax) in enumerate(axes[0:3]):
    for p in ax.patches:
        ax.annotate(f'{round(p.get_height(),2)}', (p.get_x() + p.get_width() / 2., p.get_height() + 0.025 ),
                ha='center', va='bottom',fontsize=6)
if genus_plot:
    title = 'CAMI2 Challenge Marine (genus level)'
    fig.text(0.5, 1, title, ha='center', va='bottom')
else:
    title = 'CAMI2 Challenge Marine (species level)'
    fig.text(0.5, 1, title, ha='center', va='bottom')
#axes[2].set_title("CAMI2 Challenge Marine (species level)",fontsize=7)
if cust_plot and genus_plot:
    plt.savefig("supp_figs/cami2-cust-genus.svg")
elif cust_plot and not genus_plot:
    plt.savefig("supp_figs/cami2-cust-species.svg")
elif genus_plot:
    plt.savefig("supp_figs/f2-cami2_marine_genus.svg")
else:
    plt.savefig("figures/f2-cami2_marine.svg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 19
#      17 bracken_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.bracken_2.2.profile.tsv",sep='\t')
#      18 metaphlan_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.metaphlan2_2.9.22.profile.tsv",sep='\t')
# ---> 19 kmcp_cami = pd.read_csv("kmcp_m3_test/by_tool/kmcp-se-r1.c-m3.profile.tsv",sep='\t')
#      20 motus_cami = pd.read_csv("rerun_opal/by_tool/marmgCAMI2_short_read_sample_0-9.motus_2.5.1.profile.tsv",sep='\t')
#      21 metaphlan4_cust = pd.read_csv("metaphlan4_motus_opal/by_tool/metaphlan_marine_all.profile.tsv",sep='\t')
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'kmcp_m3_test/by_tool/kmcp-se-r1.c-m3.profile.tsv'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
cm = 1/2.54
cm = 1/2.54  # centimeters in inches\n",
    ##Change this to get a bigger figure. \n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})
genus_plot = False
cust_plot = True

#sylph_cami = pd.read_csv("strmg_sylph_opal/by_tool/strmg_sylph.profile.tsv",sep='\t')
sylph_cami = pd.read_csv("sylph_strmg_v0.5_opal//by_tool/strmg_sylph_v0.5.profile.tsv",sep='\t')
bracken_cami = pd.read_csv("rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.bracken_2.2.profile.tsv",sep='\t')
metaphlan_cami = pd.read_csv("rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.metaphlan2_2.9.22.profile.tsv",sep='\t')
#kmcp_cami = pd.read_csv("kmcp_m3_test/by_tool/kmcp-se-r1.c-m3.profile.tsv",sep='\t')
motus_cami = pd.read_csv("rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.motus_2.5.1_default_norm.profile.tsv",sep='\t')
metaphlan4_cust = pd.read_csv("meta_motus_strmg_opal/by_tool/metaphlan_strain.profile.tsv",sep='\t')
motus3_cust = pd.read_csv("meta_motus_strmg_opal/by_tool/motus_strain.profile.tsv",sep='\t')

if cust_plot:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
              #      kmcp_cami.assign(method='KMCP'),
                bracken_cami.assign(method='Bracken'), 
               metaphlan_cami.assign(method='MetaPhlAn2'),
               motus_cami.assign(method='mOTUs v2.5'),
                metaphlan4_cust.assign(method='MetaPhlAn4*'),
                 motus3_cust.assign(method='mOTUs v3*'),
                     ])
elif genus_plot:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
                #        kmcp_cami.assign(method='KMCP'),
                    bracken_cami.assign(method='Bracken'), 
                   metaphlan_cami.assign(method='MetaPhlAn2'),
                   motus_cami.assign(method='mOTUs v2.5'),])
else:
    df_a = pd.concat([sylph_cami.assign(method='sylph'), 
                    #    kmcp_cami.assign(method='KMCP'),
                    bracken_cami.assign(method='Bracken'), 
                   metaphlan_cami.assign(method='MetaPhlAn2'),
                   motus_cami.assign(method='mOTUs v2.5'),])   

pc = sns.color_palette("muted")
df = df_a.loc[df_a['rank'] == 'species']
df["F1 score"] = pd.to_numeric(df["F1 score"])
df["F1 score"] = pd.to_numeric(df["F1 score"])
df["L1 norm error"] = pd.to_numeric(df["L1 norm error"])
df_g = df_a.loc[df_a['rank'] == 'genus']
df_g["L1 norm error"] = pd.to_numeric(df_g["L1 norm error"])
df_g["F1 score"] = pd.to_numeric(df_g["F1 score"])
df_g["Purity"] = pd.to_numeric(df_g["Purity"])

if genus_plot:
    p = [pc[0], pc[3], pc[4], pc[9]]
    if cust_plot:
        p.append(pc[5])
        p.append(pc[6])
    fig, axes = plt.subplots(1, 4, figsize=(16*5/5*cm, 5*cm), sharey=False)
    sns.barplot(x = 'method', y = 'F1 score', data = df_g, ax = axes[0], palette = p)
    sns.barplot(x = 'method', y = 'Purity', data = df_g, ax = axes[1], palette = p)
    sns.barplot(x = 'method', y = 'Completeness', data = df_g, ax = axes[2], palette = p)
    sns.boxplot(x = 'method', y = 'L1 norm error', data = df_g, ax = axes[3], palette = p)
    ylabels = ["F1", "Precision", "Sensitivity", "Norm. L1 (genus)"]
else:
    p = [pc[0], pc[3], pc[4], pc[9]]
    if cust_plot:
        p.append(pc[5])
        p.append(pc[6])
    if cust_plot:
        num_plots = 4
    else:
        num_plots = 5
    fig, axes = plt.subplots(1, num_plots, figsize=(16*cm, 5*cm), sharey=False)
    sns.barplot(x = 'method', y = 'F1 score', data = df, ax = axes[0], palette = p)
    sns.barplot(x = 'method', y = 'Purity', data = df, ax = axes[1], palette = p)
    sns.barplot(x = 'method', y = 'Completeness', data = df, ax = axes[2], palette = p)
    r = sns.boxplot(x = 'method', y = 'L1 norm error', data = df, ax = axes[3], palette = p)
    #r.set(yscale='log')
    if not cust_plot:
        sns.boxplot(x = 'method', y = 'L1 norm error', data = df_g, ax = axes[4], palette = p)
    ylabels = ["F1", "Precision", "Sensitivity", "Norm. L1 (species)", "Norm. L1 (genus)"]

print(df.groupby('method')['L1 norm error'].median())
print(df_g.groupby('method')['L1 norm error'].median())

for i,ax in enumerate(axes):
    if i < 3:
        ax.set_ylim([0,1])
    ax.set_xlabel("")
    sns.despine(ax=ax)
    #ax.set_ylabel(ylabels[i])
    ax.set_ylabel("")
    ax.set_title(ylabels[i], fontsize=7,pad=10)
    ax.tick_params(axis='x', rotation=75)

#fig, axes = plt.subplots(1, 3, figsize=(18*cm, 5*cm), sharey=False)
#df = df_a.loc[df_a['rank'] == 'genus']
#df["F1 score"] = pd.to_numeric(df["F1 score"])
#df["F1 score"] = pd.to_numeric(df["F1 score"])
#df["L1 norm error"] = pd.to_numeric(df["L1 norm error"])

#sns.barplot(x = 'method', y = 'F1 score', data = df, ax = axes[0], palette = p)

#sns.barplot(x = 'method', y = 'Purity', data = df, ax = axes[1], palette = p)

#sns.boxplot(x = 'method', y = 'L1 norm error', data = df, ax = axes[2], palette = p)
for (k,ax) in enumerate(axes[0:3]):
    for p in ax.patches:
        if p.get_height() > 0.99:
            ax.annotate(f'{round(p.get_height(),2)}', (p.get_x() + p.get_width() / 2., p.get_height() + 0.0 ),
                ha='center', va='bottom',fontsize=6) 
        else:
            ax.annotate(f'{round(p.get_height(),2)}', (p.get_x() + p.get_width() / 2., p.get_height() + 0.02 ),
                ha='center', va='bottom',fontsize=6)
if genus_plot:
    title = 'CAMI2 Challenge Strain Madness (genus level)'
    fig.text(0.5, 1, title, ha='center', va='bottom')
else:
    title = 'CAMI2 Challenge Strain Madness (species level)'
    fig.text(0.5, 1, title, ha='center', va='bottom')
#axes[2].set_title("CAMI2 Challenge Marine (species level)",fontsize=7)
if cust_plot and genus_plot:
    plt.savefig("supp_figs/cami2-strmg-cust-genus.svg")
elif cust_plot and not genus_plot:
    plt.savefig("supp_figs/cami2-strmg-cust-species.svg")
elif genus_plot:
    plt.savefig("supp_figs/f2-cami2_strmng_genus.svg")
else:
    plt.savefig("figures/f2-cami2_strmng.svg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 16
#      14 #sylph_cami = pd.read_csv("strmg_sylph_opal/by_tool/strmg_sylph.profile.tsv",sep='\t')
#      15 sylph_cami = pd.read_csv("sylph_strmg_v0.5_opal//by_tool/strmg_sylph_v0.5.profile.tsv",sep='\t')
# ---> 16 bracken_cami = pd.read_csv("rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.bracken_2.2.profile.tsv",sep='\t')
#      17 metaphlan_cami = pd.read_csv("rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.metaphlan2_2.9.22.profile.tsv",sep='\t')
#      18 #kmcp_cami = pd.read_csv("kmcp_m3_test/by_tool/kmcp-se-r1.c-m3.profile.tsv",sep='\t')
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~/miniforge3/lib/python3.10/site-packages/pandas/io/common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rerun_strmg_opal/by_tool/strmgCAMI2_short_read_sample_0-99.bracken_2.2.profile.tsv'

# %% [markdown]
# # Meslier et al MOCK2 real profiling

# %%
def roc( res, genus_res, truth, filename, debug = False):
    res = collapse_res(res)
    seq_abund_vec_res = []
    seq_abund_vec_truth = []

    sorted_res_vec = [(y.seq_abund,x) for x,y in res.items()] 
    sorted_res_vec.sort(reverse=True)
    ret = []
    for i in range(len(sorted_res_vec)):
        vec = sorted_res_vec[0:len(sorted_res_vec)-i]
        r = dict()
        tp = 0
        fp = 0
        num_true = len(truth)
        num_pred = len(res)
        for y,x in vec:
            r[x] = y
        for spec, data in truth.items():
            seq_abund_vec_truth.append(data.seq_abund)
            if spec in r:
                #if debug:
                #    print(truth[spec], res[spec])
                tp += 1
            else:
                if debug:
                    print(spec, data)
                #fp += 1
        for spec, data in r.items():
            if spec not in truth:
                if debug:
                    print(data)
                fp += 1
        ret.append((tp/len(truth), 1 - fp/len(r)))
        print(tp,fp, tp/len(truth), 1 - fp/len(r))
    return ret

# %%
def get_truth_skani(truth_file, ref_to_spec):
    truth = {}
    anis = []
    with open(truth_file, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            ref = row['Ref_file'].split('/')[-1]
            ref = ref.split('_genomic')[0][3:]
            spec = ref_to_spec[ref][1]
            #print(spec)
            truth[spec] = tax_result(spec, "", 0, 0)
            anis.append(float(row['ANI']))
    print('median ani r89', np.median(anis))
    return truth
            

def read_sylph_meslier(file_path, ref_to_spec):
    sample_to_taxonomic_data = dict()
    sample_to_genus_data = dict()
    with open(file_path, 'r') as f:
        csv_reader = csv.DictReader(f, delimiter='\t')
        for row in csv_reader:
            spl = row
            query = row['Sample_file']
            exp = ""
            if 'illu' in query:
                exp = 'illu'
            elif 'nano' in query:
                exp = 'nano'
            elif 'pac' in query:
                exp = 'pac'
            else:
                print("exp not found", query)
            if exp in sample_to_taxonomic_data:
                taxonomic_data = sample_to_taxonomic_data[exp]
            else:
                taxonomic_data = {}
                sample_to_taxonomic_data[exp] = taxonomic_data
            if 'Query_file' in row:
                ref = row['Query_file'].split('/')[-1].split('_genomic')[0][3:]
            else:
                ref = row['Genome_file'].split('/')[-1].split('_genomic')[0][3:]
            spec = ref_to_spec[ref]
            r = tax_result(spec[1],spec[0], float(row['Taxonomic_abundance'])/100, float(row['Sequence_abundance'])/100)
            taxonomic_data[spec[1]] = r
    for key,tax_data in sample_to_taxonomic_data.items():
        gen_data = {}
        for thing in tax_data.values():
            if thing.genus not in gen_data:
                gen_data[thing.genus] = gen_abund(thing.genus, thing.seq_abund)
            else:
                gen_data[thing.genus].seq_abund += thing.seq_abund
        sample_to_genus_data[key] = gen_data
    return (sample_to_taxonomic_data, sample_to_genus_data)

(sylph_results,sylph_gen_results) = read_sylph_meslier('meslier_results/sylph_out_meslier/sylph_output.tsv', ref_to_spec)
#(sylph_results,sylph_gen_results) = read_sylph('/mnt/disks/1tb/simulation_reads/sylph_results.tsv', ref_to_spec)

sylph_stats = dict()
kmcp_stats = dict()
ganon_stats = dict()
kraken_stats = dict()
metaphlan_stats = dict()

sylph_rocs = dict()
kmcp_rocs = dict()
ganon_rocs = dict()
kraken_rocs = dict()
metaphlan_rocs = dict()

all_stats = []
all_rocs = []
exps = ['illu','nano','pac']

truth = f'meslier_results/meslier_mock2-on_r89'
truth_data = get_truth_skani(truth,ref_to_spec)

for (i,exp) in enumerate(exps):
    if 'illu' == exp: 
        files = ['sylph',
             f'meslier_results/kmcp_out_meslier/{exp}.kmcp.profile',
             f'meslier_results/ganon_out_meslier/{exp}.ganon.tre',
            f'meslier_results/kraken_out_meslier/{exp}_bracken_species.kreport',
            f'meslier_results/metaphlan_out_meslier/{exp}.metaphlan.gtdb',
                ]
    elif 'nano' == exp:
        files = ['sylph',
             #f'/mnt/disks/1tb/chng_meslier_simulated/kmcp_out_meslier/{exp}.kmcp.profile',
            #f'/mnt/disks/1tb/chng_meslier_simulated/ganon_out_meslier/{exp}.ganon.tre',
            f'meslier_results/kraken_out_meslier/{exp}_bracken_species.kreport',
                ]  
    else:
        files = ['sylph',
             f'meslier_results/kmcp_out_meslier/{exp}.kmcp.profile',
             f'meslier_results/ganon_out_meslier/{exp}.ganon.tre',
            f'meslier_results/kraken_out_meslier/{exp}_bracken_species.kreport',
                ]  
    for result in files:
        gen_results = dict()
        #print(results)
        if 'ganon' in result:
            (results, gen_results) = read_ganon_file(result, species_name_to_spec, spec_to_metadata)
        elif 'sylph' in result:
            results = sylph_results[exp]
            #gen_results = sylph_gen_results[exp]
        elif 'kraken' in result:
            (results,gen_results) = read_kraken_file(result, species_name_to_spec, spec_to_metadata, 0.01)
        elif 'kmcp' in result:
            (results,gen_results) = read_kmcp_file(result, species_name_to_spec, spec_to_metadata)
        elif 'metaphlan' in result:
            (results,gen_results) = read_metaphlan(result, spec_to_metadata, r207_to_r89)

        debug = False
        if 'metaphlan' in result or 'sylph' in result:
            debug = False
        stats = compare_to_truth(results, gen_results, truth_data, result, debug)
        all_rocs.append((roc(results,gen_results,truth_data,result,debug), exp, result))
        all_stats.append((stats,exp,result))

    for stats,exp,result in all_stats:
        if 'sylph' in result:
            sylph_stats[exp] = stats
        if 'kmcp' in result:
            kmcp_stats[exp] = stats
        if 'ganon' in result:
            ganon_stats[exp] = stats
        if 'kraken' in result:
            kraken_stats[exp] = stats
        if 'metaphlan' in result:
            metaphlan_stats[exp] = stats

    for stats,exp,result in all_rocs:
        if 'sylph' in result:
            sylph_rocs[exp] = stats
        if 'kmcp' in result:
            kmcp_rocs[exp] = stats
        if 'ganon' in result:
            ganon_rocs[exp] = stats
        if 'kraken' in result:
            kraken_rocs[exp] = stats
        if 'metaphlan' in result:
            metaphlan_rocs[exp] = stats

cm = 1/2.54  # centimeters in inches\n",
    ##Change this to get a bigger figure. \n",
cmap = sns.color_palette("muted")
plt.rcParams.update({'font.size': 7})
plt.rcParams.update({'figure.autolayout': True})
plt.rcParams.update({'font.family':'arial'})

titles = ['Illumina','Illumina','Nanopore-old','Nanopore-old','PacBio', 'PacBio']
fig, axes = plt.subplots(1, 6, figsize=(16* cm, 5 * cm), sharey=True,gridspec_kw={'width_ratios': [4,4,2,2,4,4,]})
palette = sns.color_palette("muted")
#metric = 'precision'
for (i, exp) in enumerate(['illu', 'illu', 'nano', 'nano', 'pac', 'pac']):
    if i %2 == 0:
        metric = 'precision'
    else:
        metric = 'sensitivity'
    if exp == 'illu':
        ordered_labels = ['sylph',  'KMCP', 'Ganon', 'Bracken', 'MetaPhlAn4*']
        data = [[sylph_stats[exp][metric]], 
                [kmcp_stats[exp][metric]],
                [ganon_stats[exp][metric]],
                [kraken_stats[exp][metric]],
                [metaphlan_stats[exp][metric]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3], cmap[4]]
    elif exp == 'pac':
        ordered_labels = ['sylph', 'KMCP', 'Ganon', 'Bracken']
        data = [[sylph_stats[exp][metric]], [kmcp_stats[exp][metric]], [ganon_stats[exp][metric]], [kraken_stats[exp][metric]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3]]
    elif exp == 'nano':
        ordered_labels = ['sylph', 'Bracken']
        data = [[sylph_stats[exp][metric]], [kraken_stats[exp][metric]]]
        c = [cmap[0], cmap[3]]
    ax = sns.barplot(data = data, ax = axes[i], palette=c)
    ax.set_xticklabels(ordered_labels)
    ax.set_ylabel(metric.capitalize())
    #ax.set_title(titles[i])

    #ax.set_title(test_setups[i], fontsize=7)
    
    # Remove the top and right borders
    sns.despine(ax=ax)
    ax.tick_params(axis='x', rotation=75)

# Add this code to annotate with common titles
group_titles = ['Illumina', 'Nanopore-old', 'PacBio']
group_title_positions = [0.25, 0.565, 0.83]  # The x-position for each group title; adjust as needed
for (k,ax) in enumerate(axes):
    for p in ax.patches:
        ax.annotate(f'{round(p.get_height(),2)}', (p.get_x() + p.get_width() / 2., p.get_height() + 0.03 ),
                ha='center', va='bottom',fontsize=6)
for title, pos in zip(group_titles, group_title_positions):
    fig.text(pos, 1.00, title, ha='center', va='bottom')
if len(metaphlan_stats) > 0:
    plt.savefig('supp_figs/meslier_profiling-metaphlan.svg')
else:
    plt.savefig('figures/f3-meslier_profiling.svg')
plt.show()
# Out:
# median ani r89 100.0
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.9397590361445781 1.000003 nan 0.9069767441860465 0.975 80 78 2
# 1 sylph
# ---------------    meslier_results/kmcp_out_meslier/illu.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.860759493670886 0.9999999999999994 nan 0.7906976744186046 0.9444444444444444 72 68 4
# 1 meslier_results/kmcp_out_meslier/illu.kmcp.profile
# ---------------    meslier_results/ganon_out_meslier/illu.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.935672514619883 1.0 nan 0.9302325581395349 0.9411764705882353 85 80 5
# 1 meslier_results/ganon_out_meslier/illu.ganon.tre
# ---------------    meslier_results/kraken_out_meslier/illu_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.7885714285714287 1.0000000000000004 nan 0.8023255813953488 0.7752808988764045 89 69 20
# 1 meslier_results/kraken_out_meslier/illu_bracken_species.kreport
# ---------------    meslier_results/metaphlan_out_meslier/illu.metaphlan.gtdb
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.7848101265822784 0.9999999999999993 nan 0.7209302325581395 0.8611111111111112 72 62 10
# 1 meslier_results/metaphlan_out_meslier/illu.metaphlan.gtdb
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8108108108108107 0.9999960000000001 nan 0.6976744186046512 0.967741935483871 62 60 2
# 1 sylph
# ---------------    meslier_results/kraken_out_meslier/nano_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8461538461538463 1.0000000000000004 nan 0.8953488372093024 0.8020833333333334 96 77 19
# 1 meslier_results/kraken_out_meslier/nano_bracken_species.kreport
# ---------------    sylph
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.8774193548387097 0.9999979999999999 nan 0.7906976744186046 0.9855072463768116 69 68 1
# 1 sylph
# ---------------    meslier_results/kmcp_out_meslier/pac.kmcp.profile
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.5172413793103449 0.9999999999999998 nan 0.3488372093023256 1.0 30 30 0
# 1 meslier_results/kmcp_out_meslier/pac.kmcp.profile
# ---------------    meslier_results/ganon_out_meslier/pac.ganon.tre
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.9212121212121213 0.9999999999999999 nan 0.8837209302325582 0.9620253164556962 79 76 3
# 1 meslier_results/ganon_out_meslier/pac.ganon.tre
# ---------------    meslier_results/kraken_out_meslier/pac_bracken_species.kreport
# F1, l1 seq, l1 gen, sens, prec, number_of_predicted, num correct, num fp
# 0.759776536312849 1.0000000000000004 nan 0.7906976744186046 0.7311827956989247 93 68 25
# 1 meslier_results/kraken_out_meslier/pac_bracken_species.kreport

# %%
fig, axes = plt.subplots(1, 3, figsize=(16* cm, 5 * cm), sharey=True,gridspec_kw={'width_ratios': [2,2,2,]})

for (i, exp) in enumerate(['illu', 'nano', 'pac']):
    if exp == 'illu':
        ordered_labels = ['sylph',  'KMCP', 'Ganon', 'Bracken', 'MetaPhlAn4*']
        data = [[sylph_rocs[exp]], 
                [kmcp_rocs[exp]],
                [ganon_rocs[exp]],
                [kraken_rocs[exp]],]
               # [metaphlan_rocs[exp]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3]]
    elif exp == 'pac':
        ordered_labels = ['sylph', 'KMCP', 'Ganon', 'Bracken']
        data = [[sylph_rocs[exp]], [kmcp_rocs[exp]], [ganon_rocs[exp]], [kraken_rocs[exp]]]
        c = [cmap[0], cmap[1], cmap[2], cmap[3]]
    elif exp == 'nano':
        ordered_labels = ['sylph', 'Bracken']
        data = [[sylph_rocs[exp]], [kraken_rocs[exp]]]
        c = [cmap[0], cmap[3]]
    for j in range(len(c)):
        ax = sns.lineplot(x = [a[0] for a in data[j][0]], y =[a[1] for a in data[j][0]], ax=axes[i], color=c[j], label = ordered_labels[j])
        print(j)
    #ax.set_xticklabels(ordered_labels)
    ax.set_ylabel('Precision')
    ax.set_xlabel("Recall")
    #ax.set_title(titles[i])

    #ax.set_title(test_setups[i], fontsize=7)
    
    # Remove the top and right borders
    sns.despine(ax=ax)
    #ax.tick_params(axis='x', rotation=75)

# Add this code to annotate with common titles
group_titles = ['Illumina', 'Nanopore-old', 'PacBio']
#group_title_positions = [0.2, 0.565, 0.83]  # The x-position for each group title; adjust as needed
for (k,ax) in enumerate(axes):
    ax.legend(frameon=False)
    ax.set_title(group_titles[k])

#for title, pos in zip(group_titles, group_title_positions):
#    fig.text(pos, 1.00, title, ha='center', va='bottom')
plt.savefig('figures/roc-meslier.svg')
plt.show()
# Out:
# 0
# 1
# 2
# 3
# 0
# 1
# 0
# 1
# 2
# 3
